# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")

if api_key and api_key.startswith("sk-proj-") and len(api_key) > 10:
    print("API key looks good so far")
else:
    print(
        "There might be a problem with your API key? Please visit the troubleshooting notebook!"
    )

MODEL = "gpt-4o-mini"
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}


class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, "html.parser")
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get("href") for link in soup.find_all("a")]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)},
        ],
        response_format={"type": "json_object"},
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/deepseek-ai/DeepSeek-Prover-V2-671B',
#  '/nari-labs/Dia-1.6B',
#  '/nvidia/parakeet-tdt-0.6b-v2',
#  '/Qwen/Qwen3-235B-A22B',
#  '/JetBrains/Mellum-4b-base',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/RiverZ/ICEdit',
#  '/spaces/nari-labs/Dia-1.6B',
#  '/spaces/Qwen/Qwen3-Demo',
#  '/spaces/retwpay/waiNSFWIllustrious_v110',
#  '/spaces',
#  '/datasets/nvidia/Nemotron-CrossThink',
#  '/datasets/nvidia/OpenMathReasoning',
#  '/datasets/nvidia/OpenCodeReasoning',
#  '/datasets/rajpurkarlab/ReXGradient-160K',
#  '/datasets/deepseek-ai/DeepSeek-ProverBench',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'contact page', 'url': 'https://huggingface.co/contact'},
#   {'type': 'company page', 'url': 'https://huggingface.co/huggingface'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# deepseek-ai/DeepSeek-Prover-V2-671B
# Updated
# 6 days ago
# •
# 3.47k
# •
# 689
# nari-labs/Dia-1.6B
# Updated
# about 10 hours ago
# •
# 128k
# •
# 1.87k
# nvidia/parakeet-tdt-0.6b-v2
# Updated
# 5 days ago
# •
# 8.68k
# •
# 315
# Qwen/Qwen3-235B-A22B
# Updated
# 6 days ago
# •
# 42.8k
# •
# 699
# JetBrains/Mellum-4b-base
# Updated
# 6 days ago
# •
# 1.2k
# •
# 241
# Browse 1M+ models
# Spaces
# Running
# 6.02k
# 6.02k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 283
# 283
# ICEdit
# 🖼
# Universal Image Editing is worth a single LoRA
# Running
# on
# Zero
# 1.16k
# 1.16k
# Dia 1.6B
# 👯
# Generate realistic dialogue from a script, using Dia!
# Running
# 425
# 425
# Qwen3 Demo
# 📊
# Generate responses to user queries using conversation history
# Running
# on
# Zero
# 265
# 265
# WaiNSFWIllustrious V110
# 🖼
# Generate images from textual prompts
# Browse 400k+ applications
# Datasets
# nvidia/Nemotron-CrossThink
# Updated
# 5 days ago
# •
# 2.27k
# •
# 46
# nvidia/OpenMathReasoning
# Updated
# 13 days ago
# •
# 27.2k
# •
# 178
# nvidia/OpenCodeReasoning
# Updated
# 1 day ago
# •
# 17.4k
# •
# 349
# rajpurkarlab/ReXGradient-160K
# Updated
# about 17 hours ago
# •
# 460
# •
# 35
# deepseek-ai/DeepSeek-ProverBench
# Updated
# 6 days ago
# •
# 1.16k
# •
# 23
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 756 models
# •
# 3.21k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.81k followers
# Amazon
# company
# •
# 20 models
# •
# 3.12k followers
# Google
# company
# •
# 991 models
# •
# 12.8k followers
# Intel
# company
# •
# 220 models
# •
# 2.51k followers
# Microsoft
# company
# •
# 374 models
# •
# 12.1k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 156 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 266 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 143,907
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 28,865
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,254
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,581
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,657
# Fast tokenizers optimized for research & production
# TRL
# 13,601
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,549
# State-of-the-art ML running directly in your browser
# smolagents
# 18,026
# Smol library to build great agents in Python
# PEFT
# 18,304
# Parameter-efficient finetuning for large language models
# Datasets
# 20,071
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,083
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,684
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 35,968
# AI & ML interests
# The AI community building the future.
# Recent Activity
# lysandre
# updated
# a dataset
# about 12 hours ago
# huggingface/transformers-metadata
# Chunte
# new
# activity
# about 16 hours ago
# huggingface/badges:
# [Added Visualize this dataset]-Update README.md
# Chunte
# new
# activity
# about 16 hours ago
# huggingface/badges:
# Upload 8 files
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 42
# Team members
# 215
# +181
# +168
# +147
# +137
# +117
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 236k
# •
# 45
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 11.7M
# •
# •
# 674
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 5.4M
# •
# 187
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.44M
# •
# •
# 751
# spaces
# 26
# Sort:
# 		Recently updated
# pinned
# Running
# 85
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 157
# Inference Playground
# 🔋
# Set website theme based on user preference
# huggingface
# 1 day ago
# Running
# 390
# AI Deadlines
# ⚡
# Generate project deadlines
# huggingface
# 7 days ago
# Running
# 3
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# 18 days ago
# Running
# 88
# InferenceSupport
# 💥
# Discussions about the Inference Providers feature on the Hub
# huggingface
# 20 days ago
# Running
# 537
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Expand
# 							26
# 								spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 253
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 757
# •
# 59
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 32
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 31.8k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 187
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 31.3k
# •
# 6
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 5.08k
# •
# 21
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 43
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 84.6k
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand
# 							16
# 								models
# datasets
# 42
# Sort:
# 		Recently updated
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# about 12 hours ago
# •
# 1.65k
# •
# 1.24k
# •
# 23
# huggingface/documentation-images
# Viewer
# •
# Updated
# 5 days ago
# •
# 52
# •
# 2.91M
# •
# 61
# huggingface/badges
# Viewer
# •
# Updated
# 28 days ago
# •
# 1
# •
# 1.71M
# •
# 43
# huggingface/policy-docs
# Updated
# Mar 20
# •
# 1.17k
# •
# 10
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# Mar 15
# •
# 69
# •
# 937
# •
# 7
# huggingface/gemini-results-2025-03-03
# Viewer
# •
# Updated
# Mar 4
# •
# 17
# •
# 31
# huggingface/gemini-results-2025-02-28
# Viewer
# •
# Updated
# Mar 1
# •
# 21
# •
# 32
# huggingface/gemini-results-2025-02-27
# Viewer
# •
# Updated
# Feb 28
# •
# 24
# •
# 29
# huggingface/gemini-results-2025-02-25
# Viewer
# •
# Updated
# Feb 26
# •
# 32
# •
# 70
# huggingface/gemini-results-2025-02-24
# Viewer
# •
# Updated
# Feb 25
# •
# 32
# •
# 27
# Expand
# 							42
# 								datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 354 models
# •
# 24.6k followers
# Shopify
# Enterprise
# company
# •
# 446 followers
# Snowflake
# Enterprise
# company
# •
# 21 models
# •
# 501 followers
# Together
# Enterprise
# company
# •
# 29 models
# •
# 586 followers
# Qwen
# Enterprise
# company
# •
# 262 models
# •
# 29.5k followers
# Xsolla
# Enterprise
# company
# •
# 134 followers
# Fidelity Investments
# Enterprise
# company
# •
# 140 followers
# Jusbrasil
# Enterprise
# company
# •
# 93 followers
# IBM Granite
# Enterprise
# company
# •
# 117 models
# •
# 1.66k followers
# creditkarma
# Enterprise
# company
# •
# 64 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 69 followers
# Novo Nordisk
# Enterprise
# company
# •
# 79 followers
# Liquid AI
# Enterprise
# company
# •
# 131 followers
# Kakao Corp.
# Enterprise
# company
# •
# 3 models
# •
# 129 followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 819 followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 297 followers
# AMD
# Enterprise
# company
# •
# 130 models
# •
# 1.51k followers
# Arm
# Enterprise
# company
# •
# 192 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 128 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 228 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 110 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 153 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 422 followers
# Chegg Inc
# Enterprise
# company
# •
# 84 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 59 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# BCG X
# Enterprise
# company
# •
# 39 followers
# Twelve Labs
# Enterprise
# company
# •
# 43 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 41.8k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.81k followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 221 followers
# ServiceNow
# Enterprise
# company
# •
# 503 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 266 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 143 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 94 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 3 models
# •
# 141 followers
# Aledade Inc
# Enterprise
# company
# •
# 71 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 261 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 156 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 629 followers
# Stability AI
# Enterprise
# company
# •
# 105 models
# •
# 22.5k followers
# Adyen
# Enterprise
# company
# •
# 61 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with A100 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# How to Build an MCP Server with Gradio
# By
# abidlabs
# April 30, 2025
# •
# 78
# Community Articles
# view all
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 7 days ago
# •
# 53
# Bamba-9B-v2 - Fast and powerful!
# By
# ibm-ai-platform
# and 12 others
# •
# 8 days ago
# •
# 26
# Introducing HalluMix: A Task-Agnostic, Multi-Domain Benchmark for Detecting Hallucinations in Real-World Scenarios
# By
# quotientai
# and 3 others
# •
# 4 days ago
# •
# 18
# Creating your custom Ghibli Text-to-Image model
# By
# atlasia
# and 3 others
# •
# 6 days ago
# •
# 15
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 232
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 543
# DeepWiki: Best AI Documentation Generator for Any Github Repo
# By
# lynn-mikami
# •
# 9 days ago
# •
# 14
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 245
# Mixture of Tunable Experts - Behavior Modification of DeepSeek-R1 at Inference Time
# By
# rbrt
# and 4 others
# •
# Feb 18
# •
# 32
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 127
# A Guide to Running Qwen 3 Locally with Ollama and vLLM
# By
# lynn-mikami
# •
# 7 days ago
# •
# 7
# Building Multimodal RAG Systems: Supercharging Retrieval with MultiModal Embeddings and LLMs
# By
# Omartificial-Intelligence-Space
# •
# 5 days ago
# •
# 6
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 65
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 125
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 27
# PipelineRL
# By
# ServiceNow
# and 3 others
# •
# 11 days ago
# •
# 17
# Merge Large Language Models with mergekit
# By
# mlabonne
# •
# Jan 9, 2024
# •
# 115
# Efficient LLM Pretraining: Packed Sequences and Masked Attention
# By
# sirluk
# •
# Oct 7, 2024
# •
# 38
# What is test-time compute and how to scale it?
# By
# Kseniase
# and 1 other
# •
# Feb 6
# •
# 82
# Open-Source Handwritten Signature Detection Model
# By
# samuellimabraz
# •
# Mar 14
# •
# 109
# Welcoming Llama Guard 4 on Hugging Face Hub
# By
# merve
# April 29, 2025
# •
# 31
# The 4 Things Qwen-3's Chat Template Teaches Us
# By
# cfahlgren1
# April 30, 2025
# •
# 23
# Tiny Agents: a MCP-powered agent in 50 lines of code
# By
# julien-c
# April 25, 2025
# •
# 216
# Introducing AutoRound: Intel’s Advanced Quantization for LLMs and VLMs
# By
# wenhuach
# April 29, 2025
# •
# 20
# 17 Reasons Why Gradio Isn't Just Another UI Library
# By
# ysharma
# April 16, 2025
# •
# 29
# Cohere on Hugging Face Inference Providers 🔥
# By
# burtenshaw
# April 16, 2025
# •
# 124
# Introducing HELMET
# By
# hyen
# April 16, 2025
# •
# 23
# Hugging Face to sell open-source robots thanks to Pollen Robotics acquisition 🤖
# By
# thomwolf
# April 14, 2025
# •
# 42
# 4M Models Scanned: Protect AI + Hugging Face 6 Months In
# By
# sean-pai
# April 14, 2025
# •
# 28
# Hugging Face and Cloudflare Partner to Make Real-Time Speech and Video Seamless with FastRTC
# By
# freddyaboulton
# April 9, 2025
# •
# 24
# Arabic Leaderboards: Introducing Arabic Instruction Following, Updating AraGen, and More
# By
# alielfilali01
# April 8, 2025
# guest
# •
# 16
# Welcome Llama 4 Maverick & Scout on Hugging Face!
# By
# burtenshaw
# April 5, 2025
# •
# 142
# Journey to 1 Million Gradio Users!
# By
# abidlabs
# April 4, 2025
# •
# 26
# The NLP Course is becoming the LLM Course!
# By
# burtenshaw
# April 3, 2025
# •
# 89
# Previous
# 1
# 2
# 3
# ...
# 41
# Next
# Community Articles
# Sort:
# 		Trending
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 7 days ago
# •
# 53
# Bamba-9B-v2 - Fast and powerful!
# By
# ibm-ai-platform
# and 12 others
# •
# 8 days ago
# •
# 26
# Introducing HalluMix: A Task-Agnostic, Multi-Domain Benchmark for Detecting Hallucinations in Real-World Scenarios
# By
# quotientai
# and 3 others
# •
# 4 days ago
# •
# 18
# Creating your custom Ghibli Text-to-Image model
# By
# atlasia
# and 3 others
# •
# 6 days ago
# •
# 15
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 232
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 543
# DeepWiki: Best AI Documentation Generator for Any Github Repo
# By
# lynn-mikami
# •
# 9 days ago
# •
# 14
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 245
# Mixture of Tunable Experts - Behavior Modification of DeepSeek-R1 at Inference Time
# By
# rbrt
# and 4 others
# •
# Feb 18
# •
# 32
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 127
# A Guide to Running Qwen 3 Locally with Ollama and vLLM
# By
# lynn-mikami
# •
# 7 days ago
# •
# 7
# Building Multimodal RAG Systems: Supercharging Retrieval with MultiModal Embeddings and LLMs
# By
# Omartificial-Intelligence-Space
# •
# 5 days ago
# •
# 6
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 65
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 125
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 27
# PipelineRL
# By
# ServiceNow
# and 3 others
# •
# 11 days ago
# •
# 17
# Merge Large Language Models with mergekit
# By
# mlabonne
# •
# Jan 9, 2024
# •
# 115
# Efficient LLM Pretraining: Packed Sequences and Masked Attention
# By
# sirluk
# •
# Oct 7, 2024
# •
# 38
# What is test-time compute and how to scale it?
# By
# Kseniase
# and 1 other
# •
# Feb 6
# •
# 82
# Open-Source Handwritten Signature Detection Model
# By
# samuellimabraz
# •
# Mar 14
# •
# 109
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# models page
# Webpage Title:
# Models - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Edit Models filters
# Tasks
# Libraries
# Datasets
# Languages
# Licenses
# Other
# Multimodal
# Audio-Text-to-Text
# Image-Text-to-Text
# Visual Question Answering
# Document Question Answering
# Video-Text-to-Text
# Visual Document Retrieval
# Any-to-Any
# Computer Vision
# Depth Estimation
# Image Classification
# Object Detection
# Image Segmentation
# Text-to-Image
# Image-to-Text
# Image-to-Image
# Image-to-Video
# Unconditional Image Generation
# Video Classification
# Text-to-Video
# Zero-Shot Image Classification
# Mask Generation
# Zero-Shot Object Detection
# Text-to-3D
# Image-to-3D
# Image Feature Extraction
# Keypoint Detection
# Natural Language Processing
# Text Classification
# Token Classification
# Table Question Answering
# Question Answering
# Zero-Shot Classification
# Translation
# Summarization
# Feature Extraction
# Text Generation
# Text2Text Generation
# Fill-Mask
# Sentence Similarity
# Text Ranking
# Audio
# Text-to-Speech
# Text-to-Audio
# Automatic Speech Recognition
# Audio-to-Audio
# Audio Classification
# Voice Activity Detection
# Tabular
# Tabular Classification
# Tabular Regression
# Time Series Forecasting
# Reinforcement Learning
# Reinforcement Learning
# Robotics
# Other
# Graph Machine Learning
# Apply filters
# Models
# Full-text search
# Add filters
# Sort:
# 		Trending
# deepseek-ai/DeepSeek-Prover-V2-671B
# Text Generation
# •
# Updated
# 6 days ago
# •
# 3.47k
# •
# •
# 689
# nari-labs/Dia-1.6B
# Text-to-Speech
# •
# Updated
# about 10 hours ago
# •
# 128k
# •
# •
# 1.87k
# nvidia/parakeet-tdt-0.6b-v2
# Automatic Speech Recognition
# •
# Updated
# 5 days ago
# •
# 8.68k
# •
# 315
# Qwen/Qwen3-235B-A22B
# Text Generation
# •
# Updated
# 6 days ago
# •
# 42.8k
# •
# •
# 699
# JetBrains/Mellum-4b-base
# Text Generation
# •
# Updated
# 6 days ago
# •
# 1.2k
# •
# 241
# XiaomiMiMo/MiMo-7B-RL
# Text Generation
# •
# Updated
# 1 day ago
# •
# 3.01k
# •
# 223
# Qwen/Qwen3-30B-A3B
# Text Generation
# •
# Updated
# 7 days ago
# •
# 92k
# •
# •
# 460
# microsoft/Phi-4-reasoning-plus
# Text Generation
# •
# Updated
# 8 minutes ago
# •
# 5.02k
# •
# 202
# Qwen/Qwen2.5-Omni-3B
# Any-to-Any
# •
# Updated
# 7 days ago
# •
# 6.86k
# •
# 168
# microsoft/Phi-4-reasoning
# Text Generation
# •
# Updated
# 8 minutes ago
# •
# 3.78k
# •
# 145
# microsoft/Phi-4-mini-reasoning
# Text Generation
# •
# Updated
# 5 days ago
# •
# 4.85k
# •
# 115
# Qwen/Qwen3-8B
# Text Generation
# •
# Updated
# 7 days ago
# •
# 144k
# •
# 234
# Freepik/F-Lite
# Text-to-Image
# •
# Updated
# 7 days ago
# •
# 2.13k
# •
# 112
# unsloth/Qwen3-30B-A3B-GGUF
# Text Generation
# •
# Updated
# 4 days ago
# •
# 172k
# •
# 132
# XiaomiMiMo/MiMo-7B-Base
# Text Generation
# •
# Updated
# 1 day ago
# •
# 459
# •
# 92
# Tesslate/UIGEN-T2-7B-Q8_0-GGUF
# Text Generation
# •
# Updated
# about 1 hour ago
# •
# 1.55k
# •
# 96
# lodestones/Chroma
# Text-to-Image
# •
# Updated
# 2 days ago
# •
# 330
# Qwen/Qwen3-32B
# Text Generation
# •
# Updated
# 7 days ago
# •
# 134k
# •
# •
# 273
# Qwen/Qwen3-0.6B
# Text Generation
# •
# Updated
# 7 days ago
# •
# 164k
# •
# 199
# fdtn-ai/Foundation-Sec-8B
# Text Generation
# •
# Updated
# 6 days ago
# •
# 19.2k
# •
# 112
# ibm-granite/granite-4.0-tiny-preview
# Text Generation
# •
# Updated
# about 2 hours ago
# •
# 484
# •
# 84
# deepseek-ai/DeepSeek-Prover-V2-7B
# Updated
# 6 days ago
# •
# 3.52k
# •
# 82
# HiDream-ai/HiDream-E1-Full
# Any-to-Any
# •
# Updated
# 7 days ago
# •
# 2.51k
# •
# 129
# black-forest-labs/FLUX.1-dev
# Text-to-Image
# •
# Updated
# Aug 16, 2024
# •
# 2.67M
# •
# •
# 10.1k
# microsoft/bitnet-b1.58-2B-4T
# Text Generation
# •
# Updated
# 5 days ago
# •
# 58.8k
# •
# 940
# moonshotai/Kimi-Audio-7B-Instruct
# Text-to-Speech
# •
# Updated
# 8 days ago
# •
# 3.36k
# •
# 288
# stepfun-ai/Step1X-Edit
# Image-to-Image
# •
# Updated
# 9 days ago
# •
# •
# 252
# Qwen/Qwen3-4B
# Text Generation
# •
# Updated
# 7 days ago
# •
# 120k
# •
# •
# 158
# sanaka87/ICEdit-MoE-LoRA
# Image-to-Image
# •
# Updated
# 4 days ago
# •
# 1.7k
# •
# 65
# lightonai/GTE-ModernColBERT-v1
# Sentence Similarity
# •
# Updated
# 1 day ago
# •
# 362
# •
# 64
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# datasets page
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Edit Datasets filters
# Main
# Tasks
# Libraries
# Languages
# Licenses
# Other
# Modalities
# 3D
# Audio
# Geospatial
# Image
# Tabular
# Text
# Time-series
# Video
# Size
# 			(rows)
# Reset Size
# < 1K
# > 1T
# Format
# json
# csv
# parquet
# imagefolder
# soundfolder
# webdataset
# text
# arrow
# Apply filters
# Datasets
# 380,031
# Full-text search
# Add filters
# Sort:
# 		Trending
# nvidia/Nemotron-CrossThink
# Preview
# •
# Updated
# 5 days ago
# •
# 2.27k
# •
# 46
# nvidia/OpenMathReasoning
# Viewer
# •
# Updated
# 13 days ago
# •
# 5.47M
# •
# 27.2k
# •
# 178
# nvidia/OpenCodeReasoning
# Viewer
# •
# Updated
# 1 day ago
# •
# 753k
# •
# 17.4k
# •
# 349
# rajpurkarlab/ReXGradient-160K
# Viewer
# •
# Updated
# about 17 hours ago
# •
# 160k
# •
# 460
# •
# 35
# deepseek-ai/DeepSeek-ProverBench
# Viewer
# •
# Updated
# 6 days ago
# •
# 325
# •
# 1.16k
# •
# 23
# fka/awesome-chatgpt-prompts
# Viewer
# •
# Updated
# Jan 6
# •
# 203
# •
# 14.2k
# •
# 7.76k
# nvidia/Llama-Nemotron-Post-Training-Dataset
# Viewer
# •
# Updated
# 9 days ago
# •
# 3.91M
# •
# 10.1k
# •
# 451
# OpenGVLab/InternVL-Data
# Preview
# •
# Updated
# 42 minutes ago
# •
# 10.1k
# •
# 118
# BramVanroy/CommonCrawl-CreativeCommons
# Viewer
# •
# Updated
# 2 days ago
# •
# 739M
# •
# 749
# •
# 18
# nyuuzyou/svgfind
# Viewer
# •
# Updated
# 8 days ago
# •
# 3.66M
# •
# 425
# •
# 22
# Eureka-Lab/PHYBench
# Viewer
# •
# Updated
# 10 days ago
# •
# 1k
# •
# 2.26k
# •
# 48
# FreedomIntelligence/medical-o1-reasoning-SFT
# Viewer
# •
# Updated
# 14 days ago
# •
# 90.1k
# •
# 11.9k
# •
# 678
# HuggingFaceFW/fineweb
# Viewer
# •
# Updated
# Jan 31
# •
# 25B
# •
# 852k
# •
# 2.13k
# zwhe99/DeepMath-103K
# Viewer
# •
# Updated
# 3 days ago
# •
# 103k
# •
# 20.5k
# •
# 168
# Amod/mental_health_counseling_conversations
# Viewer
# •
# Updated
# Apr 5, 2024
# •
# 3.51k
# •
# 3.94k
# •
# 369
# Anthropic/values-in-the-wild
# Viewer
# •
# Updated
# 8 days ago
# •
# 6.91k
# •
# 1.2k
# •
# 127
# nvidia/When2Call
# Viewer
# •
# Updated
# 8 days ago
# •
# 28k
# •
# 413
# •
# 17
# quotientai/HalluMix
# Viewer
# •
# Updated
# 4 days ago
# •
# 6.5k
# •
# 272
# •
# 10
# Giova-tech/sentiment-analysis-test
# Viewer
# •
# Updated
# 20 days ago
# •
# 349
# •
# 696
# •
# 9
# Mxode/Chinese-Instruct
# Viewer
# •
# Updated
# 4 days ago
# •
# 4.85M
# •
# 1.96k
# •
# 17
# syCen/CameraBench
# Viewer
# •
# Updated
# 8 days ago
# •
# 1.07k
# •
# 3.23k
# •
# 16
# openai/gsm8k
# Viewer
# •
# Updated
# Jan 4, 2024
# •
# 17.6k
# •
# 535k
# •
# 717
# open-r1/OpenR1-Math-220k
# Viewer
# •
# Updated
# Feb 18
# •
# 450k
# •
# 28.2k
# •
# 570
# LLM360/MegaMath
# Viewer
# •
# Updated
# 27 days ago
# •
# 217M
# •
# 70.2k
# •
# 83
# Aleph-Alpha/Aleph-Alpha-GermanWeb
# Viewer
# •
# Updated
# 4 days ago
# •
# 1.89B
# •
# 1.36k
# •
# 15
# qwertychri/sentiment-analysis-test
# Viewer
# •
# Updated
# 20 days ago
# •
# 349
# •
# 614
# •
# 8
# ZennyKenny/synthetic_vc_financial_decisions_reasoning_dataset
# Viewer
# •
# Updated
# about 11 hours ago
# •
# 200
# •
# 553
# •
# 9
# open-thoughts/OpenThoughts-114k
# Viewer
# •
# Updated
# 30 days ago
# •
# 228k
# •
# 26k
# •
# 700
# Felipeit/sentiment-analysis-test
# Viewer
# •
# Updated
# 20 days ago
# •
# 349
# •
# 595
# •
# 7
# Riccardoschillaci7/sentiment-analysis-test
# Viewer
# •
# Updated
# 20 days ago
# •
# 349
# •
# 540
# •
# 7
# Previous
# 1
# 2
# 3
# ...
# 100
# Next
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# spaces page
# Webpage Title:
# Spaces - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Spaces
# ·
# The AI App Directory
# New Space
# What is Spaces?
# Image Generation
# Video Generation
# Text Generation
# Language Translation
# Speech Synthesis
# 3D Modeling
# Object Detection
# Text Analysis
# Image Editing
# Code Generation
# Question Answering
# Data Visualization
# Voice Cloning
# Background Removal
# Image Upscaling
# OCR
# Document Analysis
# Visual QA
# Image Captioning
# Chatbots
# Sentiment Analysis
# Text Summarization
# Music Generation
# Medical Imaging
# Financial Analysis
# Game AI
# Model Benchmarking
# Fine Tuning Tools
# Dataset Creation
# Pose Estimation
# Face Recognition
# Anomaly Detection
# Recommendation Systems
# Character Animation
# Style Transfer
# Image
# Spaces of the week
# 5 May 2025
# Sort:
# 		Relevance
# Running
# 425
# Qwen3 Demo
# 📊
# Generate responses to user queries using conversation history
# Qwen
# 8 days ago
# Running
# on
# Zero
# 283
# ICEdit
# 🖼
# Universal Image Editing is worth a single LoRA
# RiverZ
# 1 day ago
# Running
# 28
# ONNX Model Explorer
# 🔍
# Explore ONNX models visually
# onnx-community
# 7 days ago
# Running
# on
# Zero
# 67
# FramePack_rotate_landscape
# 🎬
# Generate videos from images and text prompts
# tori29umai
# 7 days ago
# Running
# on
# Zero
# 14
# EdgeTAM
# 🚀
# On-Device Track Anything Model
# chongzhou
# 6 days ago
# Running
# on
# Zero
# 23
# VisionScout
# 🛰
# Detect and Identify your Images
# DawnC
# 2 days ago
# Running
# 17
# WeShopAI Bad Hand Fixer
# 🖐
# Enhance hand features for flawless, natural-looking images
# WeShopAI
# 6 days ago
# Running
# 51
# Qwen3 WebGPU
# 🚀
# A hybrid reasoning model that runs locally in your browser.
# webml-community
# 8 days ago
# All running apps, trending first
# Running
# 6.02k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# enzostvs
# 19 days ago
# Running
# on
# Zero
# 283
# ICEdit
# 🖼
# Universal Image Editing is worth a single LoRA
# RiverZ
# 1 day ago
# Running
# on
# Zero
# 1.16k
# Dia 1.6B
# 👯
# Generate realistic dialogue from a script, using Dia!
# nari-labs
# 1 day ago
# Running
# 425
# Qwen3 Demo
# 📊
# Generate responses to user queries using conversation history
# Qwen
# 8 days ago
# Running
# on
# Zero
# 265
# WaiNSFWIllustrious V110
# 🖼
# Generate images from textual prompts
# retwpay
# Mar 19
# Running
# on
# Zero
# 312
# Step1X Edit
# 💻
# Edit an image based on the given instruction.
# stepfun-ai
# 8 days ago
# Running
# on
# Zero
# 270
# Describe Anything
# ⚡
# Describe image parts using masks
# nvidia
# 5 days ago
# Running
# on
# Zero
# 426
# InstantCharacter
# 🐢
# Customize characters with prompts and styles
# InstantX
# 16 days ago
# Running
# on
# Zero
# 2.52k
# Hunyuan3D-2.0
# 🌍
# Text-to-3D and Image-to-3D Generation
# tencent
# 11 days ago
# Running
# on
# Zero
# 239
# FramePack图像到视频生成(5秒限制版)
# 🎬
# Generate video from an image
# lisonallen
# 17 days ago
# Running
# on
# Zero
# 88
# FantasyTalking
# 😻
# Generate realistic talking video from image and audio
# acvlab
# 8 days ago
# Running
# on
# CPU Upgrade
# 8.64k
# Kolors Virtual Try-On
# 👕
# Try on virtual garments on person images
# Kwai-Kolors
# Sep 18, 2024
# Running
# on
# CPU Upgrade
# 94
# HiDream E1 Full
# 🚀
# Generate an edited image based on text instructions
# HiDream-ai
# 6 days ago
# Running
# on
# CPU Upgrade
# 10.1k
# AI Comic Factory
# 👩
# Create your own AI comic with a single prompt
# jbilcke-hf
# Oct 15, 2024
# Running
# 96
# FLUX Pro Unlimited
# 🔥
# Use the FLUX-Pro model as much as you want.
# NihalGazi
# about 3 hours ago
# Running
# on
# Zero
# 67
# FramePack_rotate_landscape
# 🎬
# Generate videos from images and text prompts
# tori29umai
# 7 days ago
# Running
# on
# Zero
# 1.74k
# Background Removal
# 🌘
# Remove backgrounds from images
# not-lain
# 1 day ago
# Running
# on
# Zero
# 8.23k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# black-forest-labs
# 21 days ago
# Running
# on
# Zero
# 65
# F Lite
# 🐠
# F Lite image generator
# Freepik
# 13 days ago
# Running
# on
# Zero
# 3.47k
# IC Light V2
# 📈
# Execute custom code from environment variables
# lllyasviel
# Oct 26, 2024
# Running
# on
# Zero
# 693
# UNO FLUX
# ⚡
# Generate customized images using text and multiple images
# bytedance-research
# 24 days ago
# Running
# on
# CPU Upgrade
# 5.57k
# MTEB Leaderboard
# 🥇
# Embedding Leaderboard
# mteb
# 19 days ago
# Running
# on
# Zero
# 106
# Parakeet-TDT-0.6b-V2
# Transcribe audio to text with timestamps
# nvidia
# 1 day ago
# Running
# on
# Zero
# 2.29k
# F5-TTS
# 🗣
# F5-TTS & E2-TTS: Zero-Shot Voice Cloning (Unofficial Demo)
# mrfakename
# 1 day ago
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000]  # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'contact page', 'url': 'https://huggingface.co/discuss.huggingface.co'}, {'type': 'social media page', 'url': 'https://twitter.com/huggingface'}, {'type': 'social media page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\ndeepseek-ai/DeepSeek-Prover-V2-671B\nUpdated\n6 days ago\n•\n3.47k\n•\n689\nnari-labs/Dia-1.6B\nUpdated\nabout 10 hours ago\n•\n128k\n•\n1.87k\nnvidia/parakeet-tdt-0.6b-v2\nUpdated\n5 days ago\n•\n8.68k\n•\n315\nQwen/Qwen3-235B-A22B\nUpdated\n6 days ago\n•\n42.8k\n•\n699\nJetBrains/Mellum-4b-base\nUpdated\n6 days ago\n•\n1.2k\n•\n241\nBrowse 1M+ models\nSpaces\nRunning\n6.02k\n6.02k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n283\n283\nICEdit\n🖼\nUniversal Image Editing is worth a single LoRA\nRunning\non\nZero\n1.16k\n1.16k\nDia 1.6B\n👯\nGenerate realistic dialogue from a script, using Dia!\nRunning\n425\n425\nQwen3 Demo\n📊\nGenerate responses to user queries using conversation history\nRunning\non\nZero\n265\n265\nWaiNSFWIllustrious V110\n🖼\nGenerate images from textual prompts\nBrowse 400k+ applications\nDatasets\nnvidia/Nemotron-CrossThink\nUpdated\n5 days ago\n•\n2.27k\n•\n46\nnvidia/OpenMathReasoning\nUpdated\n13 days ago\n•\n27.2k\n•\n178\nnvidia/OpenCodeReasoning\nUpdated\n1 day ago\n•\n17.4k\n•\n349\nrajpurkarlab/ReXGradient-160K\nUpdated\nabout 17 hours ago\n•\n460\n•\n35\ndeepseek-ai/DeepSeek-ProverBench\nUpdated\n6 days ago\n•\n1.16k\n•\n23\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n756 models\n•\n3.21k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.12k models\n•\n5.81k followers\nAmazon\ncompany\n•\n20 models\n•\n3.12k followers\nGoogle\ncompany\n•\n991 models\n•\n12.8k followers\nIntel\ncompany\n•\n220 models\n•\n2.51k followers\nMicrosoft\ncompany\n•\n374 models\n•\n12.1k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n156 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n266 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n143,907\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n28,865\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,254\nSafe way to store/distribute neural network weights\nHub Python Library\n2,581\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,657\nFast tokenizers optimized for research & production\nTRL\n13,601\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,549\nState-of-the-art ML running directly in your browser\nsmolagents\n18,026\nSmol library to build great agents in Python\nPEFT\n18,304\nParameter-efficient finetuning for large language models\nDatasets\n20,071\nAcc ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)},
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}]}
# # Hugging Face: The AI Community Building the Future
#
# Welcome to Hugging Face, the premier platform designed to foster collaboration within the machine learning community. Our mission is to democratize AI and equip individuals and organizations with the tools necessary to build intelligent applications.
#
# ---
#
# ## Company Overview
#
# ### Our Vision
# At Hugging Face, we believe that artificial intelligence should be accessible to everyone. By providing a collaborative environment for discovering, sharing, and building upon machine learning models, datasets, and applications, we strive to push the boundaries of what AI can achieve.
#
# ### Key Offerings
#
# - **Models**: Explore over 1 million machine learning models created by our community, ranging from text generation to image processing.
# - **Datasets**: Access and share over 250,000 datasets specifically crafted for various ML tasks.
# - **Spaces**: Develop and demo AI applications in an interactive environment encouraged by community collaboration.
#
# ### Enterprise Solutions
# We offer specialized solutions tailored for organizations, providing enterprise-grade security and dedicated support. Our services include:
#
# - Optimized Inference Endpoints for deploying applications.
# - Priority support and tools for managing projects efficiently.
# - Customizability for dedicated resource management.
#
# Pricing starts at just **$20/user/month** for enterprise clients.
#
# ---
#
# ## Who We Serve
#
# Hugging Face is trusted by more than **50,000 organizations**, including leaders like Amazon, Google, Microsoft, and Meta. Our community thrives on innovators from various sectors including education, healthcare, and technology, driving the future of AI together.
#
# ---
#
# ## Our Culture
#
# ### Innovative and Open
# The core of our culture revolves around **openness and innovation**. We are committed to building an open-source ML tooling foundation that invites contributions and fosters learning.
#
# ### Community-Driven
# More than a workplace, Hugging Face is a vibrant community where members actively collaborate and participate in discussions. We value continuous growth, sharing expertise, and celebrating achievements as a team.
#
# ---
#
# ## Careers at Hugging Face
#
# Join a team of passionate individuals working towards a common goal: democratizing AI. At Hugging Face, we offer opportunities across various domains, whether you are a developer, researcher, or in a support role.
#
# ### Why Work With Us?
#
# - **Impact**: Be part of an organization that is genuinely making a difference in the AI landscape.
# - **Culture**: Experience a supportive work environment that values teamwork and creativity.
# - **Growth**: Take advantage of opportunities for personal and professional development in a rapidly evolving industry.
#
# Explore our current job openings and embark on your journey with us!
#
# ---
#
# ## Connect with Us
#
# Stay updated with Hugging Face through our social media channels:
#
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://www.linkedin.com/company/huggingface)
# - [GitHub](https://github.com/huggingface)
#
# **Experience the future of AI with Hugging Face - where community, collaboration, and innovation come together.**

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)},
        ],
        stream=True,
    )

    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ""
        response = response.replace("```", "").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Hugging Face Brochure
#
# ---
#
# ## **About Us**
#
# Welcome to **Hugging Face**, the leading platform in **Artificial Intelligence & Machine Learning** (AI & ML). We are a community-driven organization on a mission to **democratize AI**, making it accessible for everyone. Our platform facilitates collaboration on machine learning models, datasets, and applications, enabling innovation, creativity, and the building of the future.
#
# ## **Our Offerings**
#
# ### **Models & Datasets**
# - Explore over **1 million** models and **250,000+ datasets** on our platform.
# - Collaborate on unlimited public models and datasets.
# - **Trending Models:**
#   - deepseek-ai/DeepSeek-Prover-V2-671B
#   - nari-labs/Dia-1.6B
#   - nvidia/parakeet-tdt-0.6b-v2
#
# ### **Spaces**
# - Host and contribute to **400,000+ applications** dedicated to improving machine learning.
# - Discover tools like **DeepSite** for application generation and **Dia 1.6B** for realistic dialogue generation.
#
# ### **Enterprise Solutions**
# - Our enterprise offerings include advanced features such as:
#   - Enterprise-grade security
#   - Access controls
#   - Priority support
#
# ### **Community Engagement**
# Join over **50,000 organizations** using our platform, including giants like Amazon, Google, Microsoft, and Grammarly, who collaborate on models to drive innovations in their respective sectors.
#
# ## **Company Culture**
#
# At Hugging Face, we foster a **collaborative and inclusive culture** where diversity and innovation thrive. Our **team of 215+** passionate individuals operates in a flexible environment that encourages continuous learning and sharing. We understand that collaboration is at the heart of machine learning, and we embrace a community spirit to enhance our collective capabilities.
#
# ### **Core Values:**
# - **Democratization of AI**
# - **Community Collaboration**
# - **Continuous Learning**
# - **Innovation**
#
# ## **Careers at Hugging Face**
#
# We are always on the lookout for talented individuals who share our vision of building the future of AI. Our work environment is vibrant, innovative, and heavily community-oriented. By joining our team, you’ll contribute to pioneering technology and be a part of **groundbreaking projects** that shape the future.
#
# ### **Open Positions**
# We have various roles open for individuals across:
# - Data Science
# - Software Engineering
# - Product Management
# - Marketing
# - Community Engagement
#
# Join us to be part of an impactful journey in machine learning!
#
# ## **Get Involved**
#
# Explore our site to:
# - **Join our Community:** [Sign Up](https://huggingface.co)
# - **Explore AI Apps:** Dive into our models and datasets
# - **Follow us on Social Media:**
#   - [Twitter](https://twitter.com/huggingface)
#   - [GitHub](https://github.com/huggingface)
#   - [LinkedIn](https://linkedin.com/company/huggingface)
#
# ---
#
# **Hugging Face - Together, we build the future of AI!**

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>

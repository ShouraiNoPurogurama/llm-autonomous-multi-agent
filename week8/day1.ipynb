# %% [markdown]
# # Welcome to a very busy Week 8 folder
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Especially important this week: pull the latest</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml --prune</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Just one import to start with!!

import modal

# %%
import os
os.environ["MODAL_TOKEN_ID"] = "ak-a4R1qkUwiVvn9LA6iiDRz5"
os.environ["MODAL_TOKEN_SECRET"] = "as-tswGvhXorpicT2VwWS01yQ"

# %% [markdown]
# # Setting up the modal tokens
#
# The first time you run this, please uncomment the next line and execute it.
# This is the same as running `modal setup` from the command line. It connects with Modal and installs your tokens.
#
# ## Debugging some common problems on Windows
#
# If this command fails in the next cell, or if any of the modal commands with the `!` fail, please try running them directly on the command line in an activated environment (without the `!`)
#
# A student on Windows mentioned that on Windows, you might also need to run this command from a command prompt in an activated environment afterwards:
# `modal token new`
# (Thank you Ed B. for that!)
#
# Another Windows student Minh N. mentioned you may need to use this approach, from an activated environment in the command line:
# `modal token set --token-id <your_token_id> --token-secret <your_token_secret>`
#
# Also, a student David S. mentioned the following:
# > In case anyone else using Windows hits this problem: Along with having to run `modal token new` from a command prompt, you have to move the generated token file. It will deploy the token file (.modal.toml) to your Windows profile folder. The virtual environment couldn't see that location (strangely, it couldn't even after I set environment variables for it and rebooted). I moved that token file to the folder I'm operating out of for the lab and it stopped throwing auth errors.
#
# And another Windows student (Robert M. - thank you!!) added another possible step:
#
#
# > I could not get modal to see my tokens (resulting in an 'auth error'), even after copying the ".modal.toml" file to the "week8" folder and restarting JupyterLab. The fix was to manually set the environment variables (the standard way). This config method is explained by modal on their [web site](https://modal.com/docs/reference/modal.config)
# ```
# import os
# os.environ["MODAL_TOKEN_ID"] = "xxx"
# os.environ["MODAL_TOKEN_SECRET"] = "yyy"
# ```
#
# Finally: I've also heard that in some situations, you might need to restart the Kernel of this jupyter notebook after running this. (Kernel menu >> Restart Kernel and Clear Outputs of All Cells).

# %%
# Remove the '# ' from the next line and run the cell, or run this command without the excalamation mark from an activated command prompt
# !modal setup
# Out:
# ⠋ Waiting for authentication in the web browser
# The web browser should have opened for you to authenticate and get an API
# token.
# If it didn't, please copy this URL into your web browser manually:
#
# ⠋ Waiting for authentication in the web browser
# https://modal.com/token-flow/tf-K7MSwoASyKxsC5qHxC6eaL
#
# ⠋ Waiting for authentication in the web browser
# ⠋ Waiting for authentication in the web browser
#
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
#
# Web authentication finished successfully!
# Token is connected to the shourainopurogurama workspace.
# Verifying token against https://api.modal.com
# Token verified successfully!
# ⠋ Storing token
#
# Token written to C:\Users\nhata/.modal.toml in profile shourainopurogurama.
# Warning: The MODAL_TOKEN_ID / MODAL_TOKEN_SECRET environment variables are set;
# this will override your new credentials.

# %%
from hello import app, hello, hello_europe

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# 'Hello from Ho Chi Minh City, Ho Chi Minh, VN!!'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Phoenix, Arizona, US!!'

# %% [markdown]
# ## Added thanks to student Tue H.
#
# If you look in hello.py, I've added a simple function hello_europe
#
# That uses the decorator:
# `@app.function(image=image, region="eu")`
#
# See the result below! More region specific settings are [here](https://modal.com/docs/guide/region-selection)
#
# Note that it does consume marginally more credits to specify a region.

# %%
with app.run():
    reply=hello_europe.remote()
reply
# Out:
# 'Hello from Stockholm, Stockholm, SE!!'

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **hf-secret** because that's how we refer to it in the code
# 4. Fill in your HF_TOKEN where it prompts you
#
# ### And now back to business: time to work with Llama

# %%
# This import may give a deprecation warning about adding local Python modules to the Image
# That warning can be safely ignored. You may get the same warning in other places, too..

from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Life is a mystery, everyone must stand alone, I hear")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/shourainopurogurama/main/ap-IX6Sx7ECa4cyR2DIcbfCpU
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\llama.py
# └── 🔨 Created function generate.
# Output()
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files:  25%|██▌       | 1/4 [00:55<02:47, 55.93s/it]
# Fetching 4 files:  50%|█████     | 2/4 [00:56<00:47, 23.61s/it]Fetching 4 files: 100%|██████████| 4/4 [00:56<00:00, 14.23s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:04<00:13,  4.40s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:09<00:09,  4.82s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:15<00:05,  5.47s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:16<00:00,  3.48s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:16<00:00,  4.04s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at https://modal.com/apps/shourainopurogurama/main/ap-IX6Sx7ECa4cyR2DIcbfCpU
# '<|begin_of_text|>Life is a mystery, everyone must stand alone, I hear you call my name,'

# %%
import modal
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/shourainopurogurama/main/ap-BFS9NakeqXndayVtVaeqQz
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-tleTWHhg1rDXWeyZVbPiwj
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes peft torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting peft
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tqdm (from peft)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/site-packages (from torch) (4.12.2)
# Collecting setuptools (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/setuptools/setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.21.0->accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl (362 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 199.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl (411 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl (865.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 MB 258.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 211.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 258.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 212.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 408.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 207.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 202.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 605.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 219.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 187.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 196.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 178.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 215.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 224.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 285.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl (10.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 293.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl (512 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 225.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 283.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 283.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 252.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 336.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 281.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (148 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 224.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 261.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl (128 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, urllib3, tqdm, sympy, setuptools, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, hf-xet, fsspec, filelock, charset-normalizer, triton, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# Successfully installed MarkupSafe-3.0.2 accelerate-1.7.0 bitsandbytes-0.46.0 charset-normalizer-3.4.2 filelock-3.18.0 fsspec-2025.5.1 hf-xet-1.1.2 huggingface-hub-0.32.3 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 peft-0.15.2 psutil-7.0.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.3 setuptools-80.9.0 sympy-1.14.0 tokenizers-0.21.1 torch-2.7.0 tqdm-4.67.1 transformers-4.52.4 triton-3.3.0 urllib3-2.4.0
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Saving image...
# Image saved, took 15.29s
# Built image im-tleTWHhg1rDXWeyZVbPiwj in 109.45s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_ephemeral.py
# └── 🔨 Created function price.
# Output()
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files:  25%|██▌       | 1/4 [01:00<03:02, 60.76s/it]
# Fetching 4 files:  50%|█████     | 2/4 [01:02<00:52, 26.00s/it]Fetching 4 files: 100%|██████████| 4/4 [01:02<00:00, 15.61s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:04<00:12,  4.31s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:08<00:08,  4.49s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:13<00:04,  4.57s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:13<00:00,  2.90s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:13<00:00,  3.48s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at https://modal.com/apps/shourainopurogurama/main/ap-BFS9NakeqXndayVtVaeqQz
# 133.0

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `modal deploy xxx` will deploy your code as a Deployed App
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note about secrets
#
# In both the files `pricer_service.py` and `pricer_service2.py` you will find code like this near the top:
# `secrets = [modal.Secret.from_name("hf-secret")]`
# You may need to change from `hf-secret` to `huggingface-secret` depending on how the Secret is configured in modal.
# To check, visit this page and look in the first column:
# https://modal.com/secrets/
#
# ## Important note for Windows people:
#
# On the next line, I call `modal deploy` from within Jupyter lab; I've heard that on some versions of Windows this gives a strange unicode error because modal prints emojis to the output which can't be displayed. If that happens to you, simply use an Anaconda Prompt window or a Powershell instead, with your environment activated, and type `modal deploy pricer_service` there. Follow the same approach the next time we do `!modal deploy` too.
#
# As an alternative, a few students have mentioned you can run this code within Jupyter Lab if you want to run it from here:
# ```
# # Check the default encoding
# print(locale.getpreferredencoding())  # Should print 'UTF-8'
#
# # Ensure UTF-8 encoding
# os.environ['PYTHONIOENCODING'] = 'utf-8'
# ```

# %%
# You can also run "modal deploy -m pricer_service" at the command line in an activated environment
# !modal deploy -m pricer_service
# Out:
# - Creating objects...
# | Creating objects...
# - Creating objects...
# | Creating objects...
# └── - Creating mount F:\LLM_Projects\llm_engineering\week8\pricer_service.py:
#     Uploaded 0/1 files
# - Creating objects...
# └── | Creating mount F:\LLM_Projects\llm_engineering\week8\pricer_service.py:
#     Uploaded 0/1 files
# | Creating objects...
# └── - Creating mount F:\LLM_Projects\llm_engineering\week8\pricer_service.py:
#     Finalizing index of 1 files
# - Creating objects...
# └── | Creating mount F:\LLM_Projects\llm_engineering\week8\pricer_service.py:
#     Finalizing index of 1 files
# | Creating objects...
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service.py
# └── - Creating function price...
# - Creating objects...
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service.py
# └── | Creating function price...
# \ Creating objects...
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service.py
# └── 🔨 Created function price.
#
# ✓ Created objects.
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service.py
# └── 🔨 Created function price.
# ✓ App deployed in 3.951s! 🎉
#
# View Deployment:
# https://modal.com/apps/shourainopurogurama/main/deployed/pricer-service

# %%
pricer = modal.Function.from_name("pricer-service", "price")

# %%
# This can take a while! We'll use faster approaches shortly

pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0

# %%
# You can also run "modal deploy -m pricer_service2" at the command line in an activated environment

# !modal deploy -m pricer_service2
# Out:
# - Creating objects...
# \ Creating objects...
# / Creating objects...
# └── - Creating mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py:
#     Uploaded 0/1 files
# | Creating objects...
# └── | Creating mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py:
#     Uploaded 0/1 files
# - Creating objects...
# └── - Creating mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py:
#     Finalizing index of 1 files
# | Creating objects...
# └── | Creating mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py:
#     Finalizing index of 1 files
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Building image im-GYIWwte1CqrSmrdKq2W72F
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#
# => Step 0: FROM base
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting accelerate
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting bitsandbytes
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting huggingface
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting peft
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting torch
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting transformers
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting packaging>=20.0 (from accelerate)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting psutil (from accelerate)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting pyyaml (from accelerate)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting huggingface-hub>=0.21.0 (from accelerate)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl.metadata (14 kB)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting safetensors>=0.4.3 (from accelerate)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting tqdm (from peft)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting filelock (from torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/site-packages (from torch) (4.12.2)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting setuptools (from torch)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/setuptools/setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting sympy>=1.13.3 (from torch)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting networkx (from torch)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting jinja2 (from torch)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting fsspec (from torch)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting triton==3.3.0 (from torch)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting regex!=2019.12.17 (from transformers)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting requests (from transformers)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting tokenizers<0.22,>=0.21 (from transformers)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.21.0->accelerate)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests->transformers) (3.10)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl (362 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 436.5 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl (411 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl (865.0 MB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 MB 184.4 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 408.9 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 460.4 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 391.1 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 545.8 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 418.0 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 423.7 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 520.5 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 428.6 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 441.6 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 436.7 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 450.6 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 463.9 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 483.8 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 199.2 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl (10.5 MB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 499.6 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl (512 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl (199 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 454.0 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 756.2 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 831.0 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/setuptools/setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 584.6 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 489.1 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 488.1 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 678.2 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (148 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 519.0 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 902.0 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl (128 kB)
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, huggingface, urllib3, tqdm, sympy, setuptools, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, hf-xet, fsspec, filelock, charset-normalizer, triton, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# ...
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Successfully installed MarkupSafe-3.0.2 accelerate-1.7.0 bitsandbytes-0.46.0 charset-normalizer-3.4.2 filelock-3.18.0 fsspec-2025.5.1 hf-xet-1.1.2 huggingface-0.0.1 huggingface-hub-0.32.3 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 peft-0.15.2 psutil-7.0.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.3 setuptools-80.9.0 sympy-1.14.0 tokenizers-0.21.1 torch-2.7.0 tqdm-4.67.1 transformers-4.52.4 triton-3.3.0 urllib3-2.4.0
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Saving image...
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Uploading image snapshot… --------------------- ------------ 3.7/5.9 GB 0:00:00
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Uploading image snapshot… --------------------- ------------ 3.7/5.9 GB 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Uploading image snapshot… ---------------------- ----------- 3.8/5.9 GB 0:00:00
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Uploading image snapshot… ---------------------------------  5.9/5.9 GB 0:00:00
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Image saved, took 5.04s
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#
# Built image im-GYIWwte1CqrSmrdKq2W72F in 84.90s
#
#
# / Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Building image im-H67ovNZA9cDhjVfK0qo8u8
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#
# => Step 0: FROM base
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#
# => Step 1: ENV HF_HUB_CACHE=/cache
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Saving image...
# \ Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# Image saved, took 821.01ms
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
#
# Built image im-H67ovNZA9cDhjVfK0qo8u8 in 1.84s
#
#
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# └── - Creating function Pricer.*...
# - Creating objects...
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# └── | Creating function Pricer.*...
# | Creating objects...
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.*.
# - Creating objects...
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.*.
# \ Creating objects...
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.*.
#
# ✓ Created objects.
# ├── 🔨 Created mount F:\LLM_Projects\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.*.
# ✓ App deployed in 93.358s! 🎉
#
# View Deployment:
# https://modal.com/apps/shourainopurogurama/main/deployed/pricer-service

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 133.0

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# The first time you run this modal class, it might take as much as 10 minutes to build.
# Subsequently it should be much faster.. 30 seconds if it needs to wake up, otherwise 2 seconds.
# If you want it to always be 2 seconds, you can keep the container from going to sleep by editing this constant in pricer_service2.py:
#
# `MIN_CONTAINERS = 0`
#
# Make it 1 to keep a container alive.
# But please note: this will eat up credits! Only do this if you are comfortable to have a process running continually.

# %% [markdown]
# ## And now introducing our Agent class

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# 299.0

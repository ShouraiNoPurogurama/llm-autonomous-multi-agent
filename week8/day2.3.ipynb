# %% [markdown]
# # The Price is Right
#
# Today we build a more complex solution for estimating prices of goods.
#
# 1. Day 2.0 notebook: create a RAG database with our 400,000 training data
# 2. Day 2.1 notebook: visualize in 2D
# 3. Day 2.2 notebook: visualize in 3D
# 4. Day 2.3 notebook: build and test a RAG pipeline with GPT-4o-mini
# 5. Day 2.4 notebook: (a) bring back our Random Forest pricer (b) Create a Ensemble pricer that allows contributions from all the pricers
#
# Phew! That's a lot to get through in one day!
#
# ## PLEASE NOTE:
#
# We already have a very powerful product estimator with our proprietary, fine-tuned LLM. Most people would be very satisfied with that! The main reason we're adding these extra steps is to deepen your expertise with RAG and with Agentic workflows.
#
# ## We will go fast today! Hold on to your hat..

# %%
# imports

import os
import re
import math
import json
from tqdm import tqdm
import random
from dotenv import load_dotenv
from huggingface_hub import login
import matplotlib.pyplot as plt
import numpy as np
import pickle
from openai import OpenAI
from sentence_transformers import SentenceTransformer
from datasets import load_dataset
import chromadb
from items import Item
from testing import Tester

# %%
# environment

load_dotenv(override=True)
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN', 'your-key-if-not-using-env')

# %%
openai = OpenAI()

# %%
# Load in the test pickle file
# See the section "Back to the PKL files" in the day2.0 notebook
# for instructions on obtaining this test.pkl file

with open('test.pkl', 'rb') as file:
    test = pickle.load(file)

# %%
def make_context(similars, prices):
    message = "To provide some context, here are some other items that might be similar to the item you need to estimate.\n\n"
    for similar, price in zip(similars, prices):
        message += f"Potentially related product:\n{similar}\nPrice is ${price:.2f}\n\n"
    return message

# %%
def messages_for(item, similars, prices):
    system_message = "You estimate prices of items. Reply only with the price, no explanation"
    user_prompt = make_context(similars, prices)
    user_prompt += "And now the question for you:\n\n"
    user_prompt += item.test_prompt().replace(" to the nearest dollar","").replace("\n\nPrice is $","")
    return [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_prompt},
        {"role": "assistant", "content": "Price is $"}
    ]

# %%
DB = "products_vectorstore"

# %%
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')

print(collection.count())
# Out:
# 20000

# %%
def description(item):
    text = item.prompt.replace("How much does this cost to the nearest dollar?\n\n", "")
    return text.split("\n\nPrice is $")[0]

# %%
description(test[0])
# Out:
# "OEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K"

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %%
def vector(item):
    return model.encode([description(item)])

# %%
def find_similars(item):
    results = collection.query(query_embeddings=vector(item).astype(float).tolist(), n_results=5)
    documents = results['documents'][0][:]
    prices = [m['price'] for m in results['metadatas'][0][:]]
    return documents, prices

# %%
print(test[1].prompt)
# Out:
# How much does this cost to the nearest dollar?
#
# Motorcraft YB3125 Fan Clutch
# Motorcraft YB3125 Fan Clutch Package Dimensions 25.146 cms (L) x 20.066 cms (W) x 15.494 cms (H) Package Quantity 1 Product Type Auto Part Country Of Origin China Manufacturer Motorcraft, Brand Motorcraft, Model Fan Clutch, Weight 5 pounds, Dimensions 10 x 7.63 x 6.25 inches, Country of Origin China, model number Exterior Painted, Manufacturer Part Rank Automotive Automotive Replacement Engine Fan Clutches 583, Domestic Shipping can be shipped within U.S., International Shipping This item can be shipped to select countries outside of the U.S. Learn More, Available October 10, 2007
#
# Price is $225.00

# %%
documents, prices = find_similars(test[1])

# %%
print(make_context(documents, prices))
# Out:
# To provide some context, here are some other items that might be similar to the item you need to estimate.
#
# Potentially related product:
# Four Seasons 78348 New AC Compressor
# New Compressor And Clutch Four Seasons 78348 New Nippondenso 10S17F Compressor w/ Clutch Part number 78348 Package Weight 14.55 pounds Package Dimensions 20.574 H x 28.194 L x 18.034 W (centimeters) Manufacturer Four Seasons, Brand Four Seasons, Weight 6 Pounds, Dimensions 11.3 x 7.2 x 7.8 inches, Country of Origin China, model number 78348, Manufacturer Part 78348, Voltage 120 Volts, Rank Automotive Automotive Replacement Air Conditioning Compressors 1383, Domestic Shipping can be shipped within U.S., International Shipping This item can be shipped to select countries outside of
# Price is $186.99
#
# Potentially related product:
# Motorcraft YH-23 Blower Motor Resistor
# Motorcraft YH-23 Blower Motor Resistor Package Dimensions 6.82 L x 2.36 H x 4.63 W (inches) Fit type Vehicle Specific Package Weight 1.83 pounds Country of Origin China Manufacturer MOTORCRAFT, Brand Motorcraft, Model YH23, Weight 0.01 ounces, Dimensions 4 x 1.75 x 4.06 inches, Country of Origin China, model number YH23, Is Discontinued No, Exterior Painted, Manufacturer Part YH23, OEM Part Rank Automotive Automotive Replacement Blower Motors 1555, Automotive Replacement Air Conditioning Products 6439, Available November 26, 2011
# Price is $33.55
#
# Potentially related product:
# Spal 11 Straight Blade Low Profile Fan
# Electric Cooling Fan - Medium Profile - 11 in Fan - Pusher - 962 CFM - Straight Blade - 12.20 x 11.75 x 2.48 in Thick - Plastic - Each Part Number Country Of Origin China Package Dimensions 8.89 L X 43.18 W X 45.72 H (Centimeters) Package Weight 1.995 Kilograms Brand Spal, Power Source Corded Electric, Style Modern, Dimensions 2.48\ D x 11.75\ W x 12.2\ H, Recommended Uses For Product Cooling, Wattage 12 watts, Voltage 12 Volts, Weight 3.25 pounds, Manufacturer Spal, Country of Origin China, model
# Price is $96.92
#
# Potentially related product:
# Motorcraft Compressor
# Motorcraft A/C Compressor - YCC193 Fit type Vehicle Specific Package Dimensions 18.034 H x 27.686 L x 21.59 W (centimeters) Part number YCC193 Country of Origin China Brand Motorcraft, Recommended Uses For Product Air Conditioner, Included Components A/C Compressor, Weight 15.2 Pounds, Maximum Power 21.59 Watts, Dimensions LxWxH 7.31 x 6.69 x 10.38 inches, Style Portable, Model Name A/C Compressor, Manufacturer Motorcraft, Dimensions 7.31 x 6.69 x 10.38 inches, Country of Origin China, model number Exterior Machined, Manufacturer Part Rank Automotive Automotive Replacement Air Conditioning Compress
# Price is $204.78
#
# Potentially related product:
# Clutch Kit Suzuki Carry Mazda Scrum DC51T DD51B DD51T Non-Turbo F6A Clutch Disc Cover
# Suzuki Carry Every (non-turbo) DC51T, DD51B, DD51T. Mazda Scrum (non-turbo) DJ51B DJ51T DK51B DK51T. DC51T DD51T DJ51B DJ51T DK51T DL51V DM51V 1 - Clutch Disc 170 mm x 18 teeth Aisin (Japan) 1 - Pressure Plate Aisin (Japan) 1 - Release Bearing Koyo (Japan) 1 - Pilot Bearing Koyo (Japan) Manufacturer GoldenGear, Brand GoldenGear, Weight 7.26 pounds, Dimensions
# Price is $295.00

# %%
print(messages_for(test[1], documents, prices))
# Out:
# [{'role': 'system', 'content': 'You estimate prices of items. Reply only with the price, no explanation'}, {'role': 'user', 'content': 'To provide some context, here are some other items that might be similar to the item you need to estimate.\n\nPotentially related product:\nFour Seasons 78348 New AC Compressor\nNew Compressor And Clutch Four Seasons 78348 New Nippondenso 10S17F Compressor w/ Clutch Part number 78348 Package Weight 14.55 pounds Package Dimensions 20.574 H x 28.194 L x 18.034 W (centimeters) Manufacturer Four Seasons, Brand Four Seasons, Weight 6 Pounds, Dimensions 11.3 x 7.2 x 7.8 inches, Country of Origin China, model number 78348, Manufacturer Part 78348, Voltage 120 Volts, Rank Automotive Automotive Replacement Air Conditioning Compressors 1383, Domestic Shipping can be shipped within U.S., International Shipping This item can be shipped to select countries outside of\nPrice is $186.99\n\nPotentially related product:\nMotorcraft YH-23 Blower Motor Resistor\nMotorcraft YH-23 Blower Motor Resistor Package Dimensions 6.82 L x 2.36 H x 4.63 W (inches) Fit type Vehicle Specific Package Weight 1.83 pounds Country of Origin China Manufacturer MOTORCRAFT, Brand Motorcraft, Model YH23, Weight 0.01 ounces, Dimensions 4 x 1.75 x 4.06 inches, Country of Origin China, model number YH23, Is Discontinued No, Exterior Painted, Manufacturer Part YH23, OEM Part Rank Automotive Automotive Replacement Blower Motors 1555, Automotive Replacement Air Conditioning Products 6439, Available November 26, 2011\nPrice is $33.55\n\nPotentially related product:\nSpal 11 Straight Blade Low Profile Fan\nElectric Cooling Fan - Medium Profile - 11 in Fan - Pusher - 962 CFM - Straight Blade - 12.20 x 11.75 x 2.48 in Thick - Plastic - Each Part Number Country Of Origin China Package Dimensions 8.89 L X 43.18 W X 45.72 H (Centimeters) Package Weight 1.995 Kilograms Brand Spal, Power Source Corded Electric, Style Modern, Dimensions 2.48\\ D x 11.75\\ W x 12.2\\ H, Recommended Uses For Product Cooling, Wattage 12 watts, Voltage 12 Volts, Weight 3.25 pounds, Manufacturer Spal, Country of Origin China, model\nPrice is $96.92\n\nPotentially related product:\nMotorcraft Compressor\nMotorcraft A/C Compressor - YCC193 Fit type Vehicle Specific Package Dimensions 18.034 H x 27.686 L x 21.59 W (centimeters) Part number YCC193 Country of Origin China Brand Motorcraft, Recommended Uses For Product Air Conditioner, Included Components A/C Compressor, Weight 15.2 Pounds, Maximum Power 21.59 Watts, Dimensions LxWxH 7.31 x 6.69 x 10.38 inches, Style Portable, Model Name A/C Compressor, Manufacturer Motorcraft, Dimensions 7.31 x 6.69 x 10.38 inches, Country of Origin China, model number Exterior Machined, Manufacturer Part Rank Automotive Automotive Replacement Air Conditioning Compress\nPrice is $204.78\n\nPotentially related product:\nClutch Kit Suzuki Carry Mazda Scrum DC51T DD51B DD51T Non-Turbo F6A Clutch Disc Cover\nSuzuki Carry Every (non-turbo) DC51T, DD51B, DD51T. Mazda Scrum (non-turbo) DJ51B DJ51T DK51B DK51T. DC51T DD51T DJ51B DJ51T DK51T DL51V DM51V 1 - Clutch Disc 170 mm x 18 teeth Aisin (Japan) 1 - Pressure Plate Aisin (Japan) 1 - Release Bearing Koyo (Japan) 1 - Pilot Bearing Koyo (Japan) Manufacturer GoldenGear, Brand GoldenGear, Weight 7.26 pounds, Dimensions \nPrice is $295.00\n\nAnd now the question for you:\n\nHow much does this cost?\n\nMotorcraft YB3125 Fan Clutch\nMotorcraft YB3125 Fan Clutch Package Dimensions 25.146 cms (L) x 20.066 cms (W) x 15.494 cms (H) Package Quantity 1 Product Type Auto Part Country Of Origin China Manufacturer Motorcraft, Brand Motorcraft, Model Fan Clutch, Weight 5 pounds, Dimensions 10 x 7.63 x 6.25 inches, Country of Origin China, model number Exterior Painted, Manufacturer Part Rank Automotive Automotive Replacement Engine Fan Clutches 583, Domestic Shipping can be shipped within U.S., International Shipping This item can be shipped to select countries outside of the U.S. Learn More, Available October 10, 2 ...

# %%
def get_price(s):
    s = s.replace('$','').replace(',','')
    match = re.search(r"[-+]?\d*\.\d+|\d+", s)
    return float(match.group()) if match else 0

# %%
get_price("The price for this is $99.99")
# Out:
# 99.99

# %%
# The function for gpt-4o-mini

def gpt_4o_mini_rag(item):
    documents, prices = find_similars(item)
    response = openai.chat.completions.create(
        model="gpt-4o-mini", 
        messages=messages_for(item, documents, prices),
        seed=42,
        max_tokens=5
    )
    reply = response.choices[0].message.content
    return get_price(reply)

# %%
gpt_4o_mini_rag(test[1])
# Out:
# 122.45

# %%
test[1].price
# Out:
# 225.11

# %%
Tester.test(gpt_4o_mini_rag, test)
# Out:
# 1: Guess: $312.41 Truth: $374.41 Error: $62.00 SLE: 0.03 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $122.45 Truth: $225.11 Error: $102.66 SLE: 0.37 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $45.99 Truth: $61.68 Error: $15.69 SLE: 0.08 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $399.99 Truth: $599.99 Error: $200.00 SLE: 0.16 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $18.99 Truth: $16.99 Error: $2.00 SLE: 0.01 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $12.99 Truth: $31.99 Error: $19.00 SLE: 0.74 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $99.99 Truth: $101.79 Error: $1.80 SLE: 0.00 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $269.00 Truth: $289.00 Error: $20.00 SLE: 0.01 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $499.99 Truth: $635.86 Error: $135.87 SLE: 0.06 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# 10: Guess: $99.99 Truth: $65.99 Error: $34.00 SLE: 0.17 Item: HOLDWILL 6 Pack LED Shop Light, 4FT 24W ...
# 11: Guess: $289.99 Truth: $254.21 Error: $35.78 SLE: 0.02 Item: Viking Horns V103C/1005ATK 3 Gallon Air ...
# 12: Guess: $195.99 Truth: $412.99 Error: $217.00 SLE: 0.55 Item: CURT 70110 Custom Tow Bar Base Plate Bra...
# 13: Guess: $113.50 Truth: $205.50 Error: $92.00 SLE: 0.35 Item: 10-Pack Solar HAMMERED BRONZE Finish Pos...
# 14: Guess: $219.99 Truth: $248.23 Error: $28.24 SLE: 0.01 Item: COSTWAY Electric Tumble Dryer, Sliver
# 15: Guess: $199.99 Truth: $399.00 Error: $199.01 SLE: 0.47 Item: FREE SIGNAL TV Transit 32" 12 Volt DC Po...
# 16: Guess: $365.73 Truth: $373.94 Error: $8.21 SLE: 0.00 Item: Bilstein 5100 Monotube Gas Shock Set com...
# 17: Guess: $109.99 Truth: $92.89 Error: $17.10 SLE: 0.03 Item: Sangean K-200 Multi-Function Upright AM/...
# 18: Guess: $45.00 Truth: $51.99 Error: $6.99 SLE: 0.02 Item: Charles Leonard Magnetic Lapboard Class ...
# 19: Guess: $259.99 Truth: $179.00 Error: $80.99 SLE: 0.14 Item: Gigabyte AMD Radeon HD 7870 2 GB GDDR5 D...
# 20: Guess: $11.99 Truth: $19.42 Error: $7.43 SLE: 0.20 Item: 3dRose LLC 8 x 8 x 0.25 Inches Bull Terr...
# 21: Guess: $499.00 Truth: $539.95 Error: $40.95 SLE: 0.01 Item: ROKINON 85mm F1.4 Auto Focus Full Frame ...
# 22: Guess: $149.99 Truth: $147.67 Error: $2.32 SLE: 0.00 Item: AUTOSAVER88 Headlight Assembly Compatibl...
# 23: Guess: $45.99 Truth: $24.99 Error: $21.00 SLE: 0.35 Item: ASI NAUTICAL 2.5 Inches Opera Glasses Bi...
# 24: Guess: $49.99 Truth: $149.00 Error: $99.01 SLE: 1.16 Item: Behringer TUBE OVERDRIVE TO100 Authentic...
# 25: Guess: $12.99 Truth: $16.99 Error: $4.00 SLE: 0.06 Item: Fun Express Insect Finger Puppets - 24 f...
# 26: Guess: $14.99 Truth: $7.99 Error: $7.00 SLE: 0.33 Item: WAFJAMF Roller Stamp Identity Theft Stam...
# 27: Guess: $209.99 Truth: $199.99 Error: $10.00 SLE: 0.00 Item: Capulina Tiffany Floor Lamp 2-Light 16" ...
# 28: Guess: $229.00 Truth: $251.45 Error: $22.45 SLE: 0.01 Item: Apple Watch Series 6 (GPS, 44mm) - Space...
# 29: Guess: $199.99 Truth: $231.62 Error: $31.63 SLE: 0.02 Item: ICON 01725 Tandem Axle Fender Skirt FS17...
# 30: Guess: $199.99 Truth: $135.00 Error: $64.99 SLE: 0.15 Item: SanDisk 128GB Ultra (10 Pack) MicroSD Cl...
# 31: Guess: $306.99 Truth: $356.62 Error: $49.63 SLE: 0.02 Item: Velvac 2020,L,C/Hr,W,E2003,102",Bk - 715...
# 32: Guess: $259.99 Truth: $257.99 Error: $2.00 SLE: 0.00 Item: TCMT Passenger Backrest Sissy Bar & Lugg...
# 33: Guess: $39.99 Truth: $27.99 Error: $12.00 SLE: 0.12 Item: Alnicov 63.5MM Brass Tremolo Block，Tremo...
# 34: Guess: $74.99 Truth: $171.20 Error: $96.21 SLE: 0.67 Item: Subaru Forester Outback Legacy OEM Engin...
# 35: Guess: $195.00 Truth: $225.00 Error: $30.00 SLE: 0.02 Item: Richmond Auto Upholstery - 2012 Dodge Ra...
# 36: Guess: $89.99 Truth: $105.00 Error: $15.01 SLE: 0.02 Item: AP-39 Automotive Paint Primer Grey 2K Ur...
# 37: Guess: $299.99 Truth: $299.99 Error: $0.00 SLE: 0.00 Item: Road Top Wireless Carplay Retrofit Kit D...
# 38: Guess: $698.99 Truth: $535.09 Error: $163.90 SLE: 0.07 Item: Gibson Performance Exhaust 5658 Aluminiz...
# 39: Guess: $14.99 Truth: $12.33 Error: $2.66 SLE: 0.03 Item: Bella Tunno Happy Links - Baby Montessor...
# 40: Guess: $129.99 Truth: $84.99 Error: $45.00 SLE: 0.18 Item: CANMORE H300 Handheld GPS Golf Device, S...
# 41: Guess: $19.99 Truth: $15.99 Error: $4.00 SLE: 0.04 Item: DCPOWER AC Adapter Compatible Replacemen...
# 42: Guess: $12.99 Truth: $62.44 Error: $49.45 SLE: 2.29 Item: Sharp, VX2128V, Commercial Desktop Calcu...
# 43: Guess: $114.99 Truth: $82.99 Error: $32.00 SLE: 0.10 Item: Melissa & Doug Lifelike Plush Stork Gian...
# 44: Guess: $198.00 Truth: $599.95 Error: $401.95 SLE: 1.22 Item: Sony SSCS8 2-Way 3-Driver Center Channel...
# 45: Guess: $229.99 Truth: $194.99 Error: $35.00 SLE: 0.03 Item: ASUS Chromebook CX1, 14" Full HD NanoEdg...
# 46: Guess: $399.00 Truth: $344.95 Error: $54.05 SLE: 0.02 Item: FiiO X7 32GB Hi-Res Lossless Music Playe...
# 47: Guess: $37.99 Truth: $37.99 Error: $0.00 SLE: 0.00 Item: TORRO Leather Case Compatible with iPhon...
# 48: Guess: $245.00 Truth: $224.35 Error: $20.65 SLE: 0.01 Item: Universal Air Conditioner KT 1031 A/C Co...
# 49: Guess: $835.00 Truth: $814.00 Error: $21.00 SLE: 0.00 Item: Street Series Stainless Performance Cat-...
# 50: Guess: $379.99 Truth: $439.88 Error: $59.89 SLE: 0.02 Item: Lenovo IdeaPad 3 14-inch Laptop, 14.0-in...
# 51: Guess: $278.53 Truth: $341.43 Error: $62.90 SLE: 0.04 Item: Access Bed Covers TonnoSport 22050219 - ...
# 52: Guess: $34.99 Truth: $46.78 Error: $11.79 SLE: 0.08 Item: G.I. JOE Hasbro 3 3/4" Wave 5 Action Fig...
# 53: Guess: $245.00 Truth: $171.44 Error: $73.56 SLE: 0.13 Item: T&S Brass B-0232-BST Double Pantry Fauce...
# 54: Guess: $375.00 Truth: $458.00 Error: $83.00 SLE: 0.04 Item: ZTUOAUMA Fuel Injection Pump 3090942 309...
# 55: Guess: $119.99 Truth: $130.75 Error: $10.76 SLE: 0.01 Item: 2AP18AA#ABA Hp Prime Graphing Calculator...
# 56: Guess: $24.99 Truth: $83.81 Error: $58.82 SLE: 1.40 Item: Lowrance 000-0119-83 Nmea 2000 25' Exten...
# 57: Guess: $87.99 Truth: $386.39 Error: $298.40 SLE: 2.16 Item: Jeep Genuine Accessories 82213051 Hood L...
# 58: Guess: $159.00 Truth: $169.00 Error: $10.00 SLE: 0.00 Item: GODOX CB-06 Hard Carrying Case with Whee...
# 59: Guess: $24.95 Truth: $17.95 Error: $7.00 SLE: 0.10 Item: Au-Tomotive Gold, INC. Ford Black Valet ...
# 60: Guess: $295.00 Truth: $269.00 Error: $26.00 SLE: 0.01 Item: Snailfly Black Roof Rack Rail + Cross Ba...
# 61: Guess: $99.99 Truth: $77.77 Error: $22.22 SLE: 0.06 Item: KING SHA Anti Glare LED Track Lighting H...
# 62: Guess: $89.99 Truth: $88.99 Error: $1.00 SLE: 0.00 Item: APS Compatible with Chevy Silverado 1500...
# 63: Guess: $319.99 Truth: $364.41 Error: $44.42 SLE: 0.02 Item: Wilwood Engineering 14011291R Brake Cali...
# 64: Guess: $151.28 Truth: $127.03 Error: $24.25 SLE: 0.03 Item: ACDelco Gold 336-1925A Starter, Remanufa...
# 65: Guess: $565.95 Truth: $778.95 Error: $213.00 SLE: 0.10 Item: UWS EC10783 69-Inch Matte Black Heavy-Wa...
# 66: Guess: $239.99 Truth: $206.66 Error: $33.33 SLE: 0.02 Item: Dell Latitude E5440 14in Business Laptop...
# 67: Guess: $49.99 Truth: $35.94 Error: $14.05 SLE: 0.10 Item: (Plug and Play) Spare Tire Brake Light W...
# 68: Guess: $99.99 Truth: $149.00 Error: $49.01 SLE: 0.16 Item: The Ultimate Roadside Rescue Assistant
# 69: Guess: $248.99 Truth: $251.98 Error: $2.99 SLE: 0.00 Item: Brand New 18" x 8.5" Replacement Wheel f...
# 70: Guess: $190.00 Truth: $160.00 Error: $30.00 SLE: 0.03 Item: Headlight Headlamp LH Left & RH Right Pa...
# 71: Guess: $34.99 Truth: $39.99 Error: $5.00 SLE: 0.02 Item: Lilo And Stitch Deluxe Oversize Print La...
# 72: Guess: $219.98 Truth: $362.41 Error: $142.43 SLE: 0.25 Item: AC Compressor & A/C Clutch For Hyundai A...
# 73: Guess: $340.00 Truth: $344.00 Error: $4.00 SLE: 0.00 Item: House Of Troy PIN475-AB Pinnacle Collect...
# 74: Guess: $28.99 Truth: $25.09 Error: $3.90 SLE: 0.02 Item: Juno T29 WH Floating Electrical Feed Sin...
# 75: Guess: $95.24 Truth: $175.95 Error: $80.71 SLE: 0.37 Item: Sherman GO-PARTS - for 2013-2016 Toyota ...
# 76: Guess: $109.99 Truth: $132.64 Error: $22.65 SLE: 0.03 Item: Roland RPU-3 Electronic Keyboard Pedal o...
# 77: Guess: $499.99 Truth: $422.99 Error: $77.00 SLE: 0.03 Item: Rockland VMI14 12,000 Pound 12 Volt DC E...
# 78: Guess: $150.65 Truth: $146.48 Error: $4.17 SLE: 0.00 Item: Max Advanced Brakes Elite XDS Front Cros...
# 79: Guess: $187.25 Truth: $156.83 Error: $30.42 SLE: 0.03 Item: Quality-Built 11030 Premium Quality Alte...
# 80: Guess: $129.99 Truth: $251.99 Error: $122.00 SLE: 0.43 Item: Lucida LG-510 Student Classical Guitar, ...
# 81: Guess: $329.99 Truth: $940.33 Error: $610.34 SLE: 1.09 Item: Longacre 52-79800 Aluminum Turn Plates
# 82: Guess: $34.99 Truth: $52.99 Error: $18.00 SLE: 0.16 Item: Motion Pro 08-0380 Adjustable Torque Wre...
# 83: Guess: $129.00 Truth: $219.95 Error: $90.95 SLE: 0.28 Item: Glyph Thunderbolt 3 NVMe Dock (0 GB)
# 84: Guess: $478.63 Truth: $441.03 Error: $37.60 SLE: 0.01 Item: TOYO Open Country MT Performance Radial ...
# 85: Guess: $199.99 Truth: $168.98 Error: $31.01 SLE: 0.03 Item: Razer Seiren X USB Streaming Microphone ...
# 86: Guess: $5.99 Truth: $2.49 Error: $3.50 SLE: 0.48 Item: Happy Birthday to Dad From Your Daughter...
# 87: Guess: $99.99 Truth: $98.62 Error: $1.37 SLE: 0.00 Item: Little Tikes My Real Jam First Concert S...
# 88: Guess: $59.99 Truth: $256.95 Error: $196.96 SLE: 2.08 Item: Studio M Peace and Harmony Art Pole Comm...
# 89: Guess: $19.99 Truth: $30.99 Error: $11.00 SLE: 0.18 Item: MyVolts 12V Power Supply Adaptor Compati...
# 90: Guess: $529.99 Truth: $569.84 Error: $39.85 SLE: 0.01 Item: Dell Latitude 7212 Rugged Extreme Tablet...
# 91: Guess: $109.99 Truth: $177.99 Error: $68.00 SLE: 0.23 Item: Covermates Contour Fit Car Cover - Light...
# 92: Guess: $997.99 Truth: $997.99 Error: $0.00 SLE: 0.00 Item: Westin 57-4025 Black HDX Grille Guard fi...
# 93: Guess: $329.00 Truth: $219.00 Error: $110.00 SLE: 0.16 Item: Fieldpiece JL2 Job Link Wireless App Tra...
# 94: Guess: $267.50 Truth: $225.55 Error: $41.95 SLE: 0.03 Item: hansgrohe Talis S Modern Premium Easy Cl...
# 95: Guess: $1,399.00 Truth: $495.95 Error: $903.05 SLE: 1.07 Item: G-Technology G-SPEED eS PRO High-Perform...
# 96: Guess: $549.99 Truth: $942.37 Error: $392.38 SLE: 0.29 Item: DreamLine SHDR-1960723L-01 Shower Door, ...
# 97: Guess: $18.99 Truth: $1.94 Error: $17.05 SLE: 3.67 Item: Sanctuary Square Backplate Finish: Oiled...
# 98: Guess: $209.95 Truth: $284.34 Error: $74.39 SLE: 0.09 Item: Pelican Protector 1750 Long Case - Multi...
# 99: Guess: $200.00 Truth: $171.90 Error: $28.10 SLE: 0.02 Item: Brock Replacement Driver and Passenger H...
# 100: Guess: $130.99 Truth: $144.99 Error: $14.00 SLE: 0.01 Item: Carlinkit Ai Box Mini, Android 11, Multi...
# 101: Guess: $199.00 Truth: $470.47 Error: $271.47 SLE: 0.74 Item: StarDot NetCamLIVE2 YouTube Live Stream ...
# 102: Guess: $59.99 Truth: $66.95 Error: $6.96 SLE: 0.01 Item: Atomic Compatible FILXXCAR0016 16x25x5 M...
# 103: Guess: $120.00 Truth: $117.00 Error: $3.00 SLE: 0.00 Item: Bandai Awakening of S. H. s.h.figuarts s...
# 104: Guess: $189.99 Truth: $172.14 Error: $17.85 SLE: 0.01 Item: Fit System 62135G Passenger Side Towing ...
# 105: Guess: $388.76 Truth: $392.74 Error: $3.98 SLE: 0.00 Item: Black Horse Black Aluminum Exceed Runnin...
# 106: Guess: $29.99 Truth: $16.99 Error: $13.00 SLE: 0.30 Item: Dearsun Twinkle Star Color Night Light P...
# 107: Guess: $1.75 Truth: $1.34 Error: $0.41 SLE: 0.03 Item: Pokemon - Gallade Spirit Link (83/108) -...
# 108: Guess: $249.99 Truth: $349.98 Error: $99.99 SLE: 0.11 Item: Ibanez GA34STCE-NT GIO Series Classical ...
# 109: Guess: $432.50 Truth: $370.71 Error: $61.79 SLE: 0.02 Item: Set 2 Heavy Duty 12-16.5 12x16.5 12 Ply ...
# 110: Guess: $67.99 Truth: $65.88 Error: $2.11 SLE: 0.00 Item: Hairpin Table Legs 28" Heavy Duty Hairpi...
# 111: Guess: $169.99 Truth: $229.99 Error: $60.00 SLE: 0.09 Item: Marada Racing Seat with Adjustable Slide...
# 112: Guess: $36.75 Truth: $9.14 Error: $27.61 SLE: 1.73 Item: Remington Industries 24UL1007STRWHI25 24...
# 113: Guess: $299.99 Truth: $199.00 Error: $100.99 SLE: 0.17 Item: Acer S3-391-6046 13.3-inch Ultrabook, In...
# 114: Guess: $149.99 Truth: $109.99 Error: $40.00 SLE: 0.09 Item: ICBEAMER 7" RGB LED Headlights Bulb Halo...
# 115: Guess: $434.91 Truth: $570.42 Error: $135.51 SLE: 0.07 Item: R1 Concepts Front Rear Brakes and Rotors...
# 116: Guess: $199.99 Truth: $279.99 Error: $80.00 SLE: 0.11 Item: Camplux 2.64 GPM Tankless , Outdoor Port...
# 117: Guess: $29.99 Truth: $30.99 Error: $1.00 SLE: 0.00 Item: KNOKLOCK 10 Pack 3.75 Inch(96mm) Kitchen...
# 118: Guess: $29.95 Truth: $31.99 Error: $2.04 SLE: 0.00 Item: Valley Enterprises Yaesu USB FTDI CT-62 ...
# 119: Guess: $24.99 Truth: $15.90 Error: $9.09 SLE: 0.19 Item: G9 LED Light Bulbs，8W，75W 100W replaceme...
# 120: Guess: $99.99 Truth: $45.99 Error: $54.00 SLE: 0.59 Item: ZCHAOZ 4 Lights Antique White Farmhouse ...
# 121: Guess: $199.99 Truth: $113.52 Error: $86.47 SLE: 0.32 Item: Honeywell TH8320R1003 Honeywell VisionPr...
# 122: Guess: $349.99 Truth: $516.99 Error: $167.00 SLE: 0.15 Item: Patriot Exhaust H8013-1 1-7/8" Clippster...
# 123: Guess: $125.00 Truth: $196.99 Error: $71.99 SLE: 0.20 Item: Fitrite Autopart New Front Left Driver S...
# 124: Guess: $19.99 Truth: $46.55 Error: $26.56 SLE: 0.67 Item: Technical Precision Replacement for GE G...
# 125: Guess: $292.99 Truth: $356.99 Error: $64.00 SLE: 0.04 Item: Covercraft Carhartt SeatSaver Front Row ...
# 126: Guess: $319.00 Truth: $319.95 Error: $0.95 SLE: 0.00 Item: Sennheiser SD Pro 2 (506008) - Double-Si...
# 127: Guess: $75.99 Truth: $96.06 Error: $20.07 SLE: 0.05 Item: Hitachi MAF0110 Mass Air Flow Sensor
# 128: Guess: $159.99 Truth: $190.99 Error: $31.00 SLE: 0.03 Item: AmScope SE305R-P-LED-PS36A 10X-30X LED C...
# 129: Guess: $62.99 Truth: $257.95 Error: $194.96 SLE: 1.95 Item: Front Left Driver Side Window Regulator ...
# 130: Guess: $79.99 Truth: $62.95 Error: $17.04 SLE: 0.06 Item: Premium Replica Hubcap Set, Fits Nissan ...
# 131: Guess: $24.99 Truth: $47.66 Error: $22.67 SLE: 0.39 Item: Excellerations Phonics Spelling Game for...
# 132: Guess: $299.99 Truth: $226.99 Error: $73.00 SLE: 0.08 Item: RC4WD BigDog Dual Axle Scale Car/Truck T...
# 133: Guess: $389.99 Truth: $359.95 Error: $30.04 SLE: 0.01 Item: Unknown Stage 2 Clutch Kit - Low Altitud...
# 134: Guess: $49.99 Truth: $78.40 Error: $28.41 SLE: 0.20 Item: 2002-2008 Dodge Ram 1500 Mopar 4X4 Emble...
# 135: Guess: $165.99 Truth: $172.77 Error: $6.78 SLE: 0.00 Item: Pro Comp Alloys Series 89 Wheel with Pol...
# 136: Guess: $249.99 Truth: $316.45 Error: $66.46 SLE: 0.06 Item: Detroit Axle - Front Rear Strut & Coil S...
# 137: Guess: $75.99 Truth: $87.99 Error: $12.00 SLE: 0.02 Item: ECCPP Rear Wheel Axle Replacement fit fo...
# 138: Guess: $199.99 Truth: $226.63 Error: $26.64 SLE: 0.02 Item: Dell Latitude E6520 Intel i7-2720QM 2.20...
# 139: Guess: $29.99 Truth: $31.49 Error: $1.50 SLE: 0.00 Item: F FIERCE CYCLE 251pcs Black Universal Mo...
# 140: Guess: $299.00 Truth: $196.00 Error: $103.00 SLE: 0.18 Item: Flash Furniture 4 Pk. HERCULES Series 88...
# 141: Guess: $49.99 Truth: $78.40 Error: $28.41 SLE: 0.20 Item: B&M 30287 Throttle Valve/Kickdown Cable,...
# 142: Guess: $149.99 Truth: $116.25 Error: $33.74 SLE: 0.06 Item: Gates TCK226 PowerGrip Premium Timing Be...
# 143: Guess: $139.99 Truth: $112.78 Error: $27.21 SLE: 0.05 Item: Monroe Shocks & Struts Quick-Strut 17149...
# 144: Guess: $24.99 Truth: $27.32 Error: $2.33 SLE: 0.01 Item: Feit Electric BPMR16/GU10/930CA/6 35W EQ...
# 145: Guess: $79.99 Truth: $145.91 Error: $65.92 SLE: 0.35 Item: Yellow Jacket 2806 Contractor Extension ...
# 146: Guess: $207.60 Truth: $171.09 Error: $36.51 SLE: 0.04 Item: Garage-Pro Tailgate SET Compatible with ...
# 147: Guess: $88.45 Truth: $167.95 Error: $79.50 SLE: 0.40 Item: 3M Perfect It Buffing and Polishing Kit ...
# 148: Guess: $45.50 Truth: $28.49 Error: $17.01 SLE: 0.21 Item: Chinese Style Dollhouse Model DIY Miniat...
# 149: Guess: $95.15 Truth: $122.23 Error: $27.08 SLE: 0.06 Item: Generic NRG Innovations SRK-161H Steerin...
# 150: Guess: $49.99 Truth: $32.99 Error: $17.00 SLE: 0.16 Item: Learning Resources Coding Critters Range...
# 151: Guess: $97.45 Truth: $71.20 Error: $26.25 SLE: 0.10 Item: Bosch Automotive 15463 Oxygen Sensor, OE...
# 152: Guess: $95.00 Truth: $112.75 Error: $17.75 SLE: 0.03 Item: Case of 24-2 Inch Blue Painters Tape - 6...
# 153: Guess: $114.95 Truth: $142.43 Error: $27.48 SLE: 0.05 Item: MOCA Engine Water Pump & Fan Clutch fit ...
# 154: Guess: $339.00 Truth: $398.99 Error: $59.99 SLE: 0.03 Item: SAREMAS Foot Step Bars for Hyundai Palis...
# 155: Guess: $899.99 Truth: $449.00 Error: $450.99 SLE: 0.48 Item: Gretsch G9210 Square Neck Boxcar Mahogan...
# 156: Guess: $139.99 Truth: $189.00 Error: $49.01 SLE: 0.09 Item: NikoMaku Mirror Dash Cam Front and Rear ...
# 157: Guess: $99.95 Truth: $120.91 Error: $20.96 SLE: 0.04 Item: Fenix HP25R v2.0 USB-C Rechargeable Head...
# 158: Guess: $155.00 Truth: $203.53 Error: $48.53 SLE: 0.07 Item: R&L Racing Heavy Duty Roll-Up Soft Tonne...
# 159: Guess: $299.99 Truth: $349.99 Error: $50.00 SLE: 0.02 Item: Garmin 010-02258-10 GPSMAP 64sx, Handhel...
# 160: Guess: $12.99 Truth: $34.35 Error: $21.36 SLE: 0.86 Item: Brown 5-7/8" X 8-1/2" X 3/16" Thick Heav...
# 161: Guess: $299.99 Truth: $384.99 Error: $85.00 SLE: 0.06 Item: GAOMON PD2200 Pen Display & 20 Pen Nibs ...
# 162: Guess: $199.00 Truth: $211.00 Error: $12.00 SLE: 0.00 Item: VXMOTOR for 97-03 Ford F150/F250 Lightdu...
# 163: Guess: $145.00 Truth: $129.00 Error: $16.00 SLE: 0.01 Item: HP EliteBook 2540p Intel Core i7-640LM X...
# 164: Guess: $15.99 Truth: $111.45 Error: $95.46 SLE: 3.57 Item: Green EPX Mixing Nozzles 100-Pack-fits 3...
# 165: Guess: $29.99 Truth: $81.12 Error: $51.13 SLE: 0.95 Item: Box Partners 6 1/4 x 3 1/8" 13 Pt. Manil...
# 166: Guess: $295.00 Truth: $457.08 Error: $162.08 SLE: 0.19 Item: Vixen Air 1/2" NPT Air Ride Suspension H...
# 167: Guess: $69.99 Truth: $49.49 Error: $20.50 SLE: 0.12 Item: Smart Floor Lamp, 2700-6500K+RGBPink Mul...
# 168: Guess: $29.99 Truth: $80.56 Error: $50.57 SLE: 0.94 Item: SOZG 324mm Wheelbase Body Shell RC Car B...
# 169: Guess: $305.99 Truth: $278.39 Error: $27.60 SLE: 0.01 Item: Mickey Thompson ET Street S/S Racing Rad...
# 170: Guess: $346.97 Truth: $364.50 Error: $17.53 SLE: 0.00 Item: Pirelli 275/40R20 106W XL RFT P0 PZ4-LUX...
# 171: Guess: $454.99 Truth: $378.99 Error: $76.00 SLE: 0.03 Item: Torklift C3212 Rear Tie Down
# 172: Guess: $165.26 Truth: $165.28 Error: $0.02 SLE: 0.00 Item: Cardone 78-4226 Remanufactured Ford Comp...
# 173: Guess: $129.99 Truth: $56.74 Error: $73.25 SLE: 0.67 Item: Kidde AccessPoint 001798 Supra TouchPoin...
# 174: Guess: $249.00 Truth: $307.95 Error: $58.95 SLE: 0.04 Item: 3M Protecta 3100414 Self Retracting Life...
# 175: Guess: $60.00 Truth: $38.00 Error: $22.00 SLE: 0.20 Item: Plantronics 89435-01 Wired Headset, Blac...
# 176: Guess: $79.99 Truth: $53.00 Error: $26.99 SLE: 0.16 Item: Logitech K750 Wireless Solar Keyboard fo...
# 177: Guess: $549.00 Truth: $498.00 Error: $51.00 SLE: 0.01 Item: Olympus PEN E-PL9 Body Only with 3-Inch ...
# 178: Guess: $135.50 Truth: $53.99 Error: $81.51 SLE: 0.83 Item: Beck/Arnley 051-6066 Hub & Bearing Assem...
# 179: Guess: $329.00 Truth: $350.00 Error: $21.00 SLE: 0.00 Item: Eibach Pro-Kit Performance Springs E10-6...
# 180: Guess: $199.99 Truth: $299.95 Error: $99.96 SLE: 0.16 Item: LEGO DC Batman 1989 Batwing 76161 Displa...
# 181: Guess: $95.47 Truth: $94.93 Error: $0.54 SLE: 0.00 Item: Kingston Brass KS3608PL Restoration 4-In...
# 182: Guess: $349.00 Truth: $379.00 Error: $30.00 SLE: 0.01 Item: Polk Vanishing Series 265-LS In-Wall 3-W...
# 183: Guess: $329.95 Truth: $299.95 Error: $30.00 SLE: 0.01 Item: Spec-D Tuning LED Projector Headlights G...
# 184: Guess: $19.99 Truth: $24.99 Error: $5.00 SLE: 0.05 Item: RICHMOND & FINCH Airpod Pro Case, Green ...
# 185: Guess: $85.99 Truth: $41.04 Error: $44.95 SLE: 0.53 Item: LFA Industries 43B-5A-33JT 1/16-1/2-1.5-...
# 186: Guess: $250.00 Truth: $327.90 Error: $77.90 SLE: 0.07 Item: SAUTVS LED Headlight Assembly for Slings...
# 187: Guess: $24.99 Truth: $10.99 Error: $14.00 SLE: 0.60 Item: 2 Pack Combo Womens Safety Glasses Impac...
# 188: Guess: $14.99 Truth: $14.99 Error: $0.00 SLE: 0.00 Item: Arepa - Venezuelan cuisine - Venezuela P...
# 189: Guess: $27.95 Truth: $84.95 Error: $57.00 SLE: 1.18 Item: Schlage Lock Company KS23D2300 Padlock, ...
# 190: Guess: $139.99 Truth: $111.00 Error: $28.99 SLE: 0.05 Item: Techni Mobili White Sit to Stand Mobile ...
# 191: Guess: $165.00 Truth: $123.73 Error: $41.27 SLE: 0.08 Item: Special Lite Products Contemporary Wall ...
# 192: Guess: $599.99 Truth: $557.38 Error: $42.61 SLE: 0.01 Item: Tascam DP-24SD 24-Track Digital Portastu...
# 193: Guess: $79.00 Truth: $95.55 Error: $16.55 SLE: 0.04 Item: Glow Lighting 636CC10SP Vista Crystal Fl...
# 194: Guess: $159.95 Truth: $154.00 Error: $5.95 SLE: 0.00 Item: Z3 Wind Deflector, Smoke Tint, Lexan, Wi...
# 195: Guess: $149.99 Truth: $198.99 Error: $49.00 SLE: 0.08 Item: Olympus E-20 5MP Digital Camera w/ 4x Op...
# 196: Guess: $159.99 Truth: $430.44 Error: $270.45 SLE: 0.97 Item: PHYNEDI 1:1000 World Trade Center (1973-...
# 197: Guess: $19.99 Truth: $45.67 Error: $25.68 SLE: 0.64 Item: YANGHUAN Unstable Unicorns Adventure Car...
# 198: Guess: $99.99 Truth: $249.00 Error: $149.01 SLE: 0.82 Item: Interlogix NX-1820E NetworX Touch Screen...
# 199: Guess: $59.99 Truth: $42.99 Error: $17.00 SLE: 0.11 Item: Steering Damper,Universal Motorcycle Han...
# 200: Guess: $199.99 Truth: $181.33 Error: $18.66 SLE: 0.01 Item: Amprobe TIC 410A Hot Stick Attachment
# 201: Guess: $2.99 Truth: $6.03 Error: $3.04 SLE: 0.32 Item: MyCableMart 3.5mm Plug/Jack, 4 Conductor...
# 202: Guess: $44.95 Truth: $29.99 Error: $14.96 SLE: 0.16 Item: OtterBox + Pop Symmetry Series Case for ...
# 203: Guess: $749.99 Truth: $899.00 Error: $149.01 SLE: 0.03 Item: Dell XPS X8700-1572BLK Desktop ( Intel C...
# 204: Guess: $399.99 Truth: $399.99 Error: $0.00 SLE: 0.00 Item: Franklin Iron Works Sperry Industrial Br...
# 205: Guess: $12.75 Truth: $4.66 Error: $8.09 SLE: 0.79 Item: Avery Legal Dividers, Standard Collated ...
# 206: Guess: $340.00 Truth: $261.41 Error: $78.59 SLE: 0.07 Item: Moen 8346 Commercial Posi-Temp Pressure ...
# 207: Guess: $119.99 Truth: $136.97 Error: $16.98 SLE: 0.02 Item: Carlisle Versa Trail ATR All Terrain Rad...
# 208: Guess: $199.00 Truth: $79.00 Error: $120.00 SLE: 0.84 Item: SUNWAYFOTO 44mm Tripod Ball Head Arca Co...
# 209: Guess: $199.00 Truth: $444.99 Error: $245.99 SLE: 0.64 Item: NanoBeam AC NBE-5AC-Gen2-US 4 Units 5GHz...
# 210: Guess: $412.75 Truth: $411.94 Error: $0.81 SLE: 0.00 Item: WULF 4" Front 2" Rear Leveling Lift Kit ...
# 211: Guess: $307.00 Truth: $148.40 Error: $158.60 SLE: 0.52 Item: Alera ALEVABFMC Valencia Series Mobile B...
# 212: Guess: $109.99 Truth: $244.99 Error: $135.00 SLE: 0.63 Item: YU-GI-OH! Ignition Assault Booster Box
# 213: Guess: $88.99 Truth: $86.50 Error: $2.49 SLE: 0.00 Item: 48" x 36" Extra-Large Framed Magnetic Bl...
# 214: Guess: $99.99 Truth: $297.95 Error: $197.96 SLE: 1.18 Item: Dell Latitude D620 Renewed Notebook PC
# 215: Guess: $499.99 Truth: $399.99 Error: $100.00 SLE: 0.05 Item: acer Aspire 5 Laptop, AMD Ryzen 3 5300U ...
# 216: Guess: $295.00 Truth: $599.00 Error: $304.00 SLE: 0.50 Item: Elk 31080/6RC-GRN 30 by 6-Inch Viva 6-Li...
# 217: Guess: $39.99 Truth: $105.99 Error: $66.00 SLE: 0.92 Item: Barbie Top Model Doll
# 218: Guess: $449.99 Truth: $689.00 Error: $239.01 SLE: 0.18 Item: Danby Designer 20-In. Electric Range wit...
# 219: Guess: $299.99 Truth: $404.99 Error: $105.00 SLE: 0.09 Item: FixtureDisplays® Metal Truss Podium Doub...
# 220: Guess: $216.75 Truth: $207.76 Error: $8.99 SLE: 0.00 Item: ACDelco 13597235 GM Original Equipment A...
# 221: Guess: $312.90 Truth: $171.82 Error: $141.08 SLE: 0.36 Item: EBC S1KF1135 Stage-1 Premium Street Brak...
# 222: Guess: $359.99 Truth: $293.24 Error: $66.75 SLE: 0.04 Item: FXR Men's Boost FX Jacket (Black/Orange/...
# 223: Guess: $599.95 Truth: $374.95 Error: $225.00 SLE: 0.22 Item: SuperATV Scratch Resistant 3-in-1 Flip W...
# 224: Guess: $101.99 Truth: $111.99 Error: $10.00 SLE: 0.01 Item: SBU 3 Layer All Weather Mini Van Car Cov...
# 225: Guess: $45.99 Truth: $42.99 Error: $3.00 SLE: 0.00 Item: 2 Pack Outdoor Brochure Holder Advertisi...
# 226: Guess: $139.99 Truth: $116.71 Error: $23.28 SLE: 0.03 Item: Monroe Shocks & Struts Quick-Strut 17158...
# 227: Guess: $165.99 Truth: $118.61 Error: $47.38 SLE: 0.11 Item: Elements of Design Magellan EB235AL Thre...
# 228: Guess: $197.99 Truth: $147.12 Error: $50.87 SLE: 0.09 Item: GM Genuine Parts 15-62961 Air Conditioni...
# 229: Guess: $159.99 Truth: $119.99 Error: $40.00 SLE: 0.08 Item: Baseus 17-in-1 USB C Docking Station to ...
# 230: Guess: $199.00 Truth: $369.98 Error: $170.98 SLE: 0.38 Item: Whitehall™ Personalized Whitehall Capito...
# 231: Guess: $339.99 Truth: $315.55 Error: $24.44 SLE: 0.01 Item: Pro Circuit Works Pipe PY05250 for 02-19...
# 232: Guess: $299.99 Truth: $190.99 Error: $109.00 SLE: 0.20 Item: HYANKA 15 "1200W Professional DJ Speaker...
# 233: Guess: $175.00 Truth: $155.00 Error: $20.00 SLE: 0.01 Item: Bluetooth X6BT Card Reader Writer Encode...
# 234: Guess: $399.99 Truth: $349.99 Error: $50.00 SLE: 0.02 Item: AIRAID Cold Air Intake System by K&N: In...
# 235: Guess: $169.99 Truth: $249.99 Error: $80.00 SLE: 0.15 Item: Bostingner Shower Faucets Sets Complete,...
# 236: Guess: $59.99 Truth: $42.99 Error: $17.00 SLE: 0.11 Item: PIT66 Front Bumper Turn Signal Lights, C...
# 237: Guess: $14.99 Truth: $17.99 Error: $3.00 SLE: 0.03 Item: Caseology Bumpy Compatible with Google P...
# 238: Guess: $249.99 Truth: $425.00 Error: $175.01 SLE: 0.28 Item: Fleck 2510 Timer Mechanical Filter Contr...
# 239: Guess: $199.99 Truth: $249.99 Error: $50.00 SLE: 0.05 Item: Haloview MC7108 Wireless RV Backup Camer...
# 240: Guess: $39.99 Truth: $138.23 Error: $98.24 SLE: 1.50 Item: Schmidt Spiele - Manhattan
# 241: Guess: $259.99 Truth: $414.99 Error: $155.00 SLE: 0.22 Item: Corsa 14333 Tip Kit (Ford Mustang GT)
# 242: Guess: $115.00 Truth: $168.28 Error: $53.28 SLE: 0.14 Item: Hoshizaki FM116A Fan Motor Kit 1
# 243: Guess: $289.00 Truth: $199.99 Error: $89.01 SLE: 0.13 Item: BAINUO Antler Chandelier Lighting,6 Ligh...
# 244: Guess: $189.99 Truth: $126.70 Error: $63.29 SLE: 0.16 Item: DNA MOTORING HL-OH-FEXP06-SM-AM Smoke Le...
# 245: Guess: $10.99 Truth: $5.91 Error: $5.08 SLE: 0.30 Item: Wera Stainless 3840/1 TS 2.5mm Hex Inser...
# 246: Guess: $199.95 Truth: $193.06 Error: $6.89 SLE: 0.00 Item: Celestron - PowerSeeker 127EQ Telescope ...
# 247: Guess: $139.99 Truth: $249.99 Error: $110.00 SLE: 0.33 Item: NHOPEEW 10.1inch Android Car Radio Carpl...
# 248: Guess: $75.00 Truth: $64.12 Error: $10.88 SLE: 0.02 Item: Other Harmonica (Suzuki-2Timer24- A)
# 249: Guess: $149.99 Truth: $114.99 Error: $35.00 SLE: 0.07 Item: Harley Air Filter Venturi Intake Air Cle...
# 250: Guess: $1,249.00 Truth: $926.00 Error: $323.00 SLE: 0.09 Item: Elite Screens Edge Free Ambient Light Re...

# %% [markdown]
# ## Optional Extra: Trying a DeepSeek API call instead of OpenAI
#
# If you have a DeepSeek API key, we will use it here as an alternative implementation; otherwise skip to the next section..

# %%
# Connect to DeepSeek using the OpenAI client python library

deepseek_api_key = os.getenv("DEEPSEEK_API_KEY")
deepseek_via_openai_client = OpenAI(api_key=deepseek_api_key,base_url="https://api.deepseek.com")

# %%
# Added some retry logic here because DeepSeek is very oversubscribed and sometimes fails..

def deepseek_api_rag(item):
    documents, prices = find_similars(item)
    retries = 8
    done = False
    while not done and retries > 0:
        try:
            response = deepseek_via_openai_client.chat.completions.create(
                model="deepseek-chat", 
                messages=messages_for(item, documents, prices),
                seed=42,
                max_tokens=8
            )
            reply = response.choices[0].message.content
            done = True
        except Exception as e:
            print(f"Error: {e}")
            retries -= 1
    return get_price(reply)

# %%
deepseek_api_rag(test[1])

# %%
Tester.test(deepseek_api_rag, test)

# %% [markdown]
# ## And now to wrap this in an "Agent" class

# %%
from agents.frontier_agent import FrontierAgent

# %%
# Let's print the logs so we can see what's going on

import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
agent = FrontierAgent(collection)

# %%
agent.price("Quadcast HyperX condenser mic for high quality podcasting")

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent2 = SpecialistAgent()

# %%
agent2.price("Quadcast HyperX condenser mic for high quality podcasting")
